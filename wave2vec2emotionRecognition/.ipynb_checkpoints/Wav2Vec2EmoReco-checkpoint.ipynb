# %%
import os 
import tokenizer
import librosa
import pandas as pd
import jiwer
from huggingface_hub import notebook_login
# !pip install datasets==1.18.3
# !pip install transformers==4.17.0
notbook_login()
import sys
list = sys.path
print(list)
# Out:
# Requirement already satisfied: datasets==1.18.3 in /Users/mac/anaconda3/lib/python3.11/site-packages (1.18.3)
# Requirement already satisfied: numpy>=1.17 in /Users/mac/anaconda3/lib/python3.11/site-packages (from datasets==1.18.3) (1.23.5)
# Requirement already satisfied: pyarrow!=4.0.0,>=3.0.0 in /Users/mac/anaconda3/lib/python3.11/site-packages (from datasets==1.18.3) (11.0.0)
# Requirement already satisfied: dill in /Users/mac/anaconda3/lib/python3.11/site-packages (from datasets==1.18.3) (0.3.8)
# Requirement already satisfied: pandas in /Users/mac/anaconda3/lib/python3.11/site-packages (from datasets==1.18.3) (2.0.3)
# Requirement already satisfied: requests>=2.19.0 in /Users/mac/anaconda3/lib/python3.11/site-packages (from datasets==1.18.3) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /Users/mac/anaconda3/lib/python3.11/site-packages (from datasets==1.18.3) (4.65.0)
# Requirement already satisfied: xxhash in /Users/mac/anaconda3/lib/python3.11/site-packages (from datasets==1.18.3) (2.0.2)
# Requirement already satisfied: multiprocess in /Users/mac/anaconda3/lib/python3.11/site-packages (from datasets==1.18.3) (0.70.16)
# Requirement already satisfied: fsspec>=2021.05.0 in /Users/mac/anaconda3/lib/python3.11/site-packages (from fsspec[http]>=2021.05.0->datasets==1.18.3) (2023.4.0)
# Requirement already satisfied: aiohttp in /Users/mac/anaconda3/lib/python3.11/site-packages (from datasets==1.18.3) (3.8.5)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.1.0 in /Users/mac/anaconda3/lib/python3.11/site-packages (from datasets==1.18.3) (0.17.3)
# Requirement already satisfied: packaging in /Users/mac/anaconda3/lib/python3.11/site-packages (from datasets==1.18.3) (23.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/mac/anaconda3/lib/python3.11/site-packages (from aiohttp->datasets==1.18.3) (22.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /Users/mac/anaconda3/lib/python3.11/site-packages (from aiohttp->datasets==1.18.3) (2.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/mac/anaconda3/lib/python3.11/site-packages (from aiohttp->datasets==1.18.3) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /Users/mac/anaconda3/lib/python3.11/site-packages (from aiohttp->datasets==1.18.3) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/mac/anaconda3/lib/python3.11/site-packages (from aiohttp->datasets==1.18.3) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/mac/anaconda3/lib/python3.11/site-packages (from aiohttp->datasets==1.18.3) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/mac/anaconda3/lib/python3.11/site-packages (from aiohttp->datasets==1.18.3) (1.2.0)
# Requirement already satisfied: filelock in /Users/mac/anaconda3/lib/python3.11/site-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets==1.18.3) (3.9.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/mac/anaconda3/lib/python3.11/site-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets==1.18.3) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/mac/anaconda3/lib/python3.11/site-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets==1.18.3) (4.10.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/mac/anaconda3/lib/python3.11/site-packages (from requests>=2.19.0->datasets==1.18.3) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/mac/anaconda3/lib/python3.11/site-packages (from requests>=2.19.0->datasets==1.18.3) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/mac/anaconda3/lib/python3.11/site-packages (from requests>=2.19.0->datasets==1.18.3) (2023.7.22)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/mac/anaconda3/lib/python3.11/site-packages (from pandas->datasets==1.18.3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/mac/anaconda3/lib/python3.11/site-packages (from pandas->datasets==1.18.3) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/mac/anaconda3/lib/python3.11/site-packages (from pandas->datasets==1.18.3) (2023.3)
# Requirement already satisfied: six>=1.5 in /Users/mac/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->datasets==1.18.3) (1.16.0)
# Requirement already satisfied: transformers==4.17.0 in /Users/mac/anaconda3/lib/python3.11/site-packages (4.17.0)
# Requirement already satisfied: filelock in /Users/mac/anaconda3/lib/python3.11/site-packages (from transformers==4.17.0) (3.9.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /Users/mac/anaconda3/lib/python3.11/site-packages (from transformers==4.17.0) (0.17.3)
# Requirement already satisfied: numpy>=1.17 in /Users/mac/anaconda3/lib/python3.11/site-packages (from transformers==4.17.0) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /Users/mac/anaconda3/lib/python3.11/site-packages (from transformers==4.17.0) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /Users/mac/anaconda3/lib/python3.11/site-packages (from transformers==4.17.0) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /Users/mac/anaconda3/lib/python3.11/site-packages (from transformers==4.17.0) (2022.7.9)
# Requirement already satisfied: requests in /Users/mac/anaconda3/lib/python3.11/site-packages (from transformers==4.17.0) (2.31.0)
# Requirement already satisfied: sacremoses in /Users/mac/anaconda3/lib/python3.11/site-packages (from transformers==4.17.0) (0.1.1)
# Requirement already satisfied: tokenizers!=0.11.3,>=0.11.1 in /Users/mac/anaconda3/lib/python3.11/site-packages (from transformers==4.17.0) (0.13.2)
# Requirement already satisfied: tqdm>=4.27 in /Users/mac/anaconda3/lib/python3.11/site-packages (from transformers==4.17.0) (4.65.0)
# Requirement already satisfied: fsspec in /Users/mac/anaconda3/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.1.0->transformers==4.17.0) (2023.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/mac/anaconda3/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.1.0->transformers==4.17.0) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/mac/anaconda3/lib/python3.11/site-packages (from requests->transformers==4.17.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/mac/anaconda3/lib/python3.11/site-packages (from requests->transformers==4.17.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/mac/anaconda3/lib/python3.11/site-packages (from requests->transformers==4.17.0) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/mac/anaconda3/lib/python3.11/site-packages (from requests->transformers==4.17.0) (2023.7.22)
# Requirement already satisfied: click in /Users/mac/anaconda3/lib/python3.11/site-packages (from sacremoses->transformers==4.17.0) (8.1.7)
# Requirement already satisfied: joblib in /Users/mac/anaconda3/lib/python3.11/site-packages (from sacremoses->transformers==4.17.0) (1.2.0)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 9
#       7 get_ipython().system('pip install datasets==1.18.3')
#       8 get_ipython().system('pip install transformers==4.17.0')
# ----> 9 notbook_login()
#      10 import sys
#      11 list = sys.path
#
# NameError: name 'notbook_login' is not defined

# %%
df_train = pd.read_csv('DataSets/TIMIT/train_data.csv')
df_train = df_train[:8400]
df_train
# Out:
#        index test_or_train dialect_region speaker_id       filename  \
# 0        1.0         TRAIN            DR4      MMDM0  SI681.WAV.wav
# 1        2.0         TRAIN            DR4      MMDM0     SI1311.PHN
# 2        3.0         TRAIN            DR4      MMDM0     SI1311.WRD
# 3        4.0         TRAIN            DR4      MMDM0      SX321.PHN
# 4        5.0         TRAIN            DR4      MMDM0      SX321.WRD
# ...      ...           ...            ...        ...            ...
# 8395  8396.0         TRAIN            DR2      MMAA0    SA2.WAV.wav
# 8396  8397.0         TRAIN            DR2      MMAA0  SX125.WAV.wav
# 8397  8398.0         TRAIN            DR2      MMAA0      SI845.WAV
# 8398  8399.0         TRAIN            DR2      MMAA0       SX35.TXT
# 8399  8400.0         TRAIN            DR2      MMAA0   SX35.WAV.wav
#
#                  path_from_data_dir        path_from_data_dir_windows  \
# 0     TRAIN/DR4/MMDM0/SI681.WAV.wav  TRAIN\\DR4\\MMDM0\\SI681.WAV.wav
# 1        TRAIN/DR4/MMDM0/SI1311.PHN     TRAIN\\DR4\\MMDM0\\SI1311.PHN
# 2        TRAIN/DR4/MMDM0/SI1311.WRD     TRAIN\\DR4\\MMDM0\\SI1311.WRD
# 3         TRAIN/DR4/MMDM0/SX321.PHN      TRAIN\\DR4\\MMDM0\\SX321.PHN
# 4         TRAIN/DR4/MMDM0/SX321.WRD      TRAIN\\DR4\\MMDM0\\SX321.WRD
# ...                             ...                               ...
# 8395    TRAIN/DR2/MMAA0/SA2.WAV.wav    TRAIN\\DR2\\MMAA0\\SA2.WAV.wav
# 8396  TRAIN/DR2/MMAA0/SX125.WAV.wav  TRAIN\\DR2\\MMAA0\\SX125.WAV.wav
# 8397      TRAIN/DR2/MMAA0/SI845.WAV      TRAIN\\DR2\\MMAA0\\SI845.WAV
# 8398       TRAIN/DR2/MMAA0/SX35.TXT       TRAIN\\DR2\\MMAA0\\SX35.TXT
# 8399   TRAIN/DR2/MMAA0/SX35.WAV.wav   TRAIN\\DR2\\MMAA0\\SX35.WAV.wav
#
#      is_converted_audio is_audio is_word_file is_phonetic_file  \
# 0                  True     True        False            False
# 1                 False    False        False             True
# 2                 False    False         True            False
# 3                 False    False        False             True
# 4                 False    False         True            False
# ...                 ...      ...          ...              ...
# 8395               True     True        False            False
# 8396               True     True        False            False
# 8397              False     True        False            False
# 8398              False    False        False            False
# 8399               True     True        False            False
#
#      is_sentence_file
# 0               False
# 1               False
# 2               False
# 3               False
# 4               False
# ...               ...
# 8395            False
# 8396            False
# 8397            False
# 8398             True
# 8399            False
#
# [8400 rows x 12 columns]

# %%
from datasets import load_dataset, load_metric

timit = load_dataset("timit_asr")
# Out:
# Reusing dataset timit_asr (/Users/mac/.cache/huggingface/datasets/timit_asr/clean/2.0.1/b11b576ddcccbcefa7c9f0c4e6c2a43756f3033adffe0fb686aa61043d0450ad)
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
timit = timit.remove_columns(["phonetic_detail", "word_detail", "dialect_region", "id", "sentence_type", "speaker_id"])
timit
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['file', 'audio', 'text'],
#         num_rows: 4620
#     })
#     test: Dataset({
#         features: ['file', 'audio', 'text'],
#         num_rows: 1680
#     })
# })

# %%
from datasets import ClassLabel
import random

from IPython.display import display, HTML

def show_random_elements(dataset, num_examples=10):
    assert num_examples <= len(dataset), "Can't pick more elements than there are in the dataset."
    picks = []
    for _ in range(num_examples):
        pick = random.randint(0, len(dataset)-1)
        while pick in picks:
            pick = random.randint(0, len(dataset)-1)
        picks.append(pick)
    
    df = pd.DataFrame(dataset[picks])
    display(HTML(df.to_html()))

show_random_elements(timit["train"].remove_columns(["file", "audio"]))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>She had your dark suit in greasy wash water all year.</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Don't ask me to carry an oily rag like that.</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Don't ask me to carry an oily rag like that.</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>We got drenched from the uninterrupted rain.</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Sometimes strong stress serves to focus an important secondary relationship.</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>You always come up with pathological examples.</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Biologists use radioactive isotopes to study microorganisms.</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>My desires are simple: give me one informative paragraph on the subject.</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>We'll serve rhubarb pie after Rachel's talk.</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Share bath, maybe -- but share refrigerator?</td>
#     </tr>
#   </tbody>
# </table>

# %%
import re
chars_to_ignore_regex = '[\,\?\.\!\-\;\:\"]'

def remove_special_characters(batch):
    batch["text"] = re.sub(chars_to_ignore_regex, '', batch["text"]).lower()
    return batch

timit = timit.map(remove_special_characters)
# Out:
# Parameter 'function'=<function remove_special_characters at 0x128d94860> of the transform datasets.arrow_dataset.Dataset._map_single couldn't be hashed properly, a random hash was used instead. Make sure your transforms and parameters are serializable with pickle or dill for the dataset fingerprinting and caching to work. If you reuse this transform, the caching mechanism will consider it to be different from the previous calls and recompute everything. This warning is only showed once. Subsequent hashing failures won't be showed.
# 0ex [00:00, ?ex/s]
# 0ex [00:00, ?ex/s]

# %%
show_random_elements(timit["train"].remove_columns(["file", "audio"]))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>it's illegal to postdate a check</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>how would you evaluate this algebraic expression</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>don't ask me to carry an oily rag like that</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>don't ask me to carry an oily rag like that</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>the social and psychological consequences of this continue to affect the area</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>again the analyticity of the two curves guarantees that such intervals exist</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>during one reading an image appeared of a prisoner in irons</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>his scalp was blistered from today's hot sun</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>don't ask me to carry an oily rag like that</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>she had your dark suit in greasy wash water all year</td>
#     </tr>
#   </tbody>
# </table>

# %%
def extract_all_chars(batch):
  all_text = " ".join(batch["text"])
  vocab = list(set(all_text))
  return {"vocab": [vocab], "all_text": [all_text]}

vocabs = timit.map(extract_all_chars, batched=True, batch_size=-1, keep_in_memory=True, remove_columns=timit.column_names["train"])
# Out:
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]

# %%
vocab_list = list(set(vocabs["train"]["vocab"][0]) | set(vocabs["test"]["vocab"][0]))

vocab_dict = {v: k for k, v in enumerate(vocab_list)}
vocab_dict
# Out:
# {'q': 0,
#  'f': 1,
#  'x': 2,
#  'j': 3,
#  'k': 4,
#  'p': 5,
#  'y': 6,
#  'n': 7,
#  'u': 8,
#  's': 9,
#  't': 10,
#  'l': 11,
#  'i': 12,
#  'e': 13,
#  'g': 14,
#  'd': 15,
#  'a': 16,
#  'r': 17,
#  'b': 18,
#  'm': 19,
#  'w': 20,
#  'o': 21,
#  ' ': 22,
#  'c': 23,
#  "'": 24,
#  'h': 25,
#  'v': 26,
#  'z': 27}

# %%
vocab_dict["|"] = vocab_dict[" "]
del vocab_dict[" "]

# %%
vocab_dict["[UNK]"] = len(vocab_dict)
vocab_dict["[PAD]"] = len(vocab_dict)
print(len(vocab_dict))
# Out:
# 30

# %%
import json
with open('vocab.json', 'w') as vocab_file:
    json.dump(vocab_dict, vocab_file)

# %%
repo_name = "wav2vec2-base-timit-demo-colab"

# %%
tokenizer.push_to_hub(repo_name)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 tokenizer.push_to_hub(repo_name)
#
# AttributeError: module 'tokenizer' has no attribute 'push_to_hub'

# %%
from transformers import Wav2Vec2CTCTokenizer

tokenizer = Wav2Vec2CTCTokenizer("./vocab.json", unk_token="[UNK]", pad_token="[PAD]", word_delimiter_token="|")

# %%
from transformers import Wav2Vec2FeatureExtractor

feature_extractor = Wav2Vec2FeatureExtractor(feature_size=1, sampling_rate=16000, padding_value=0.0, do_normalize=True, return_attention_mask=False)

# %%
from transformers import Wav2Vec2Processor

processor = Wav2Vec2Processor(feature_extractor=feature_extractor, tokenizer=tokenizer)

# %%
timit['train']['audio']
# Out:
# [{'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MMDM0/SI681.WAV',
#   'array': array([-2.1362305e-04,  6.1035156e-05,  3.0517578e-05, ...,
#          -3.0517578e-05, -9.1552734e-05, -6.1035156e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MMDM0/SA2.WAV',
#   'array': array([-3.6621094e-04,  9.1552734e-05, -3.0517578e-05, ...,
#           3.0517578e-05, -6.1035156e-05,  0.0000000e+00], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MMDM0/SX411.WAV',
#   'array': array([ 2.7465820e-04, -9.1552734e-05,  3.0517578e-05, ...,
#           0.0000000e+00,  3.0517578e-05, -3.0517578e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MMDM0/SA1.WAV',
#   'array': array([ 1.8310547e-04, -1.5258789e-04, -3.0517578e-05, ...,
#           3.0517578e-05,  6.1035156e-05,  3.0517578e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MMDM0/SX231.WAV',
#   'array': array([-3.0517578e-05, -3.0517578e-05, -6.1035156e-05, ...,
#          -3.0517578e-05,  3.0517578e-05,  0.0000000e+00], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MMDM0/SX51.WAV',
#   'array': array([-3.0517578e-05, -3.0517578e-05,  3.0517578e-05, ...,
#           3.0517578e-05,  0.0000000e+00,  9.1552734e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MMDM0/SX141.WAV',
#   'array': array([ 1.2207031e-04,  6.1035156e-05,  6.1035156e-05, ...,
#          -6.1035156e-05,  3.0517578e-05, -6.1035156e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MMDM0/SI1941.WAV',
#   'array': array([-1.5258789e-04,  6.1035156e-05,  6.1035156e-05, ...,
#           6.1035156e-05, -3.0517578e-05,  9.1552734e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MMDM0/SI1311.WAV',
#   'array': array([ 2.7465820e-04, -1.2207031e-04,  0.0000000e+00, ...,
#           3.0517578e-05,  0.0000000e+00,  3.0517578e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MMDM0/SX321.WAV',
#   'array': array([ 0.0000000e+00,  9.1552734e-05,  3.0517578e-05, ...,
#          -3.0517578e-05, -3.0517578e-05,  6.1035156e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MCSS0/SX300.WAV',
#   'array': array([3.3569336e-04, 0.0000000e+00, 6.1035156e-05, ..., 3.3569336e-04,
#          3.0517578e-04, 4.2724609e-04], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MCSS0/SX210.WAV',
#   'array': array([-2.1362305e-04,  0.0000000e+00, -3.0517578e-05, ...,
#           0.0000000e+00,  1.2207031e-04, -3.0517578e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MCSS0/SI750.WAV',
#   'array': array([-1.9836426e-03,  5.7983398e-04, -2.1362305e-04, ...,
#           0.0000000e+00, -3.0517578e-05,  1.2207031e-04], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MCSS0/SI1380.WAV',
#   'array': array([3.9672852e-04, 3.0517578e-04, 3.0517578e-04, ..., 3.0517578e-05,
#          6.1035156e-05, 1.2207031e-04], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MCSS0/SA2.WAV',
#   'array': array([ 1.5258789e-04,  0.0000000e+00, -3.0517578e-05, ...,
#           0.0000000e+00,  2.7465820e-04,  1.2207031e-04], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MCSS0/SA1.WAV',
#   'array': array([-3.3569336e-04,  2.1362305e-04, -9.1552734e-05, ...,
#           6.1035156e-05,  2.1362305e-04,  1.5258789e-04], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MCSS0/SX390.WAV',
#   'array': array([0.00012207, 0.        , 0.00012207, ..., 0.        , 0.        ,
#          0.00027466], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MCSS0/SX30.WAV',
#   'array': array([ 0.0000000e+00, -3.0517578e-04, -1.8310547e-04, ...,
#           9.1552734e-05,  6.1035156e-05,  6.1035156e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MCSS0/SI688.WAV',
#   'array': array([ 1.5258789e-04, -3.0517578e-05,  3.0517578e-05, ...,
#           1.2207031e-04,  0.0000000e+00,  6.1035156e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MCSS0/SX120.WAV',
#   'array': array([ 9.1552734e-05, -1.5258789e-04, -2.1362305e-04, ...,
#          -9.1552734e-05, -9.1552734e-05,  1.2207031e-04], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MCDR0/SI524.WAV',
#   'array': array([ 6.1035156e-05, -9.1552734e-05,  1.8310547e-04, ...,
#          -3.0517578e-05,  9.1552734e-05,  6.1035156e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MCDR0/SX164.WAV',
#   'array': array([5.1879883e-04, 6.1035156e-04, 4.5776367e-04, ..., 3.0517578e-05,
#          3.0517578e-05, 3.0517578e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MCDR0/SI1784.WAV',
#   'array': array([1.8310547e-04, 1.5258789e-04, 1.5258789e-04, ..., 0.0000000e+00,
#          3.0517578e-05, 3.0517578e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MCDR0/SA2.WAV',
#   'array': array([-4.8828125e-04,  6.1035156e-05, -6.1035156e-05, ...,
#           2.4414062e-04,  1.8310547e-04, -1.5258789e-04], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MCDR0/SI1154.WAV',
#   'array': array([0.00012207, 0.        , 0.00012207, ..., 0.00018311, 0.00027466,
#          0.00036621], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MCDR0/SX74.WAV',
#   'array': array([-6.1035156e-05,  9.1552734e-05, -9.1552734e-05, ...,
#           9.1552734e-05,  6.1035156e-05,  4.5776367e-04], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MCDR0/SA1.WAV',
#   'array': array([ 0.0000000e+00, -6.1035156e-05,  0.0000000e+00, ...,
#          -3.6621094e-04, -2.1362305e-04, -9.1552734e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MCDR0/SX344.WAV',
#   'array': array([-9.1552734e-05,  0.0000000e+00,  0.0000000e+00, ...,
#          -5.7983398e-04, -5.1879883e-04, -5.1879883e-04], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MCDR0/SX434.WAV',
#   'array': array([0.0000000e+00, 0.0000000e+00, 1.2207031e-04, ..., 0.0000000e+00,
#          0.0000000e+00, 6.1035156e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MCDR0/SX254.WAV',
#   'array': array([ 9.1552734e-05, -9.1552734e-05,  3.0517578e-05, ...,
#           0.0000000e+00, -3.0517578e-05,  1.5258789e-04], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MLEL0/SI1246.WAV',
#   'array': array([-3.9672852e-04,  6.1035156e-05, -6.1035156e-05, ...,
#           3.0517578e-05,  3.6621094e-04,  1.2207031e-04], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MLEL0/SI1876.WAV',
#   'array': array([ 1.8310547e-04, -3.0517578e-05,  0.0000000e+00, ...,
#           1.5258789e-04,  9.1552734e-05,  2.1362305e-04], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MLEL0/SX166.WAV',
#   'array': array([3.3569336e-04, 9.1552734e-04, 9.1552734e-04, ..., 0.0000000e+00,
#          6.1035156e-05, 0.0000000e+00], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MLEL0/SA2.WAV',
#   'array': array([ 5.7983398e-04, -2.7465820e-04,  1.2207031e-04, ...,
#          -3.0517578e-05,  3.0517578e-05, -9.1552734e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MLEL0/SX76.WAV',
#   'array': array([ 3.0517578e-04, -9.1552734e-05,  3.0517578e-05, ...,
#           3.0517578e-05, -3.0517578e-05, -3.0517578e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MLEL0/SA1.WAV',
#   'array': array([ 1.5258789e-04, -3.0517578e-05,  3.0517578e-05, ...,
#          -1.2207031e-04, -1.5258789e-04,  0.0000000e+00], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MLEL0/SX436.WAV',
#   'array': array([ 3.0517578e-04,  0.0000000e+00,  9.1552734e-05, ...,
#           9.1552734e-05, -6.1035156e-05,  6.1035156e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MLEL0/SX346.WAV',
#   'array': array([8.8500977e-04, 6.1035156e-05, 4.8828125e-04, ..., 3.0517578e-05,
#          6.1035156e-05, 9.1552734e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MLEL0/SI616.WAV',
#   'array': array([9.1552734e-05, 3.0517578e-05, 0.0000000e+00, ..., 3.0517578e-05,
#          0.0000000e+00, 1.5258789e-04], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MLEL0/SX256.WAV',
#   'array': array([ 4.2724609e-04, -6.1035156e-05,  6.1035156e-05, ...,
#           3.0517578e-05,  6.1035156e-05,  9.1552734e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/FEEH0/SX302.WAV',
#   'array': array([-1.8310547e-04,  2.1362305e-04,  3.3569336e-04, ...,
#          -3.0517578e-05, -3.0517578e-05,  3.0517578e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/FEEH0/SI1742.WAV',
#   'array': array([ 0.0000000e+00, -1.5258789e-04, -9.1552734e-05, ...,
#           1.2207031e-04,  0.0000000e+00,  3.0517578e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/FEEH0/SX212.WAV',
#   'array': array([ 2.7465820e-04, -1.2207031e-04, -5.4931641e-04, ...,
#          -3.0517578e-05,  0.0000000e+00,  1.2207031e-04], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/FEEH0/SA2.WAV',
#   'array': array([2.7465820e-04, 0.0000000e+00, 3.0517578e-05, ..., 6.1035156e-05,
#          1.2207031e-04, 6.1035156e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/FEEH0/SA1.WAV',
#   'array': array([-3.0517578e-05,  2.7465820e-04,  0.0000000e+00, ...,
#           0.0000000e+00,  3.0517578e-05,  6.1035156e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/FEEH0/SX392.WAV',
#   'array': array([0.0000000e+00, 3.0517578e-05, 1.5258789e-04, ..., 6.1035156e-05,
#          9.1552734e-05, 3.0517578e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/FEEH0/SI471.WAV',
#   'array': array([ 2.1362305e-04,  3.0517578e-05,  1.8310547e-04, ...,
#           0.0000000e+00,  3.0517578e-05, -3.0517578e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/FEEH0/SX32.WAV',
#   'array': array([ 4.2724609e-04, -2.1362305e-04, -3.0517578e-05, ...,
#          -1.2207031e-04, -1.2207031e-04, -3.0517578e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/FEEH0/SI1112.WAV',
#   'array': array([-3.0517578e-04, -3.0517578e-05, -6.1035156e-05, ...,
#           1.8310547e-04, -6.1035156e-05,  3.6621094e-04], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/FEEH0/SX122.WAV',
#   'array': array([6.1035156e-05, 2.7465820e-04, 2.7465820e-04, ..., 6.1035156e-05,
#          6.1035156e-05, 9.1552734e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MFWK0/SX259.WAV',
#   'array': array([-3.6621094e-04,  1.2207031e-04, -6.1035156e-05, ...,
#           9.1552734e-05, -1.5258789e-04,  7.0190430e-04], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MFWK0/SI619.WAV',
#   'array': array([ 0.0000000e+00,  6.1035156e-05, -3.0517578e-05, ...,
#           1.5258789e-04,  1.5258789e-04,  1.5258789e-04], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MFWK0/SA2.WAV',
#   'array': array([ 1.2207031e-04, -9.1552734e-05, -3.0517578e-05, ...,
#          -3.0517578e-05,  1.2207031e-04,  3.0517578e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MFWK0/SX439.WAV',
#   'array': array([-2.1362305e-04,  6.1035156e-05, -3.0517578e-05, ...,
#          -1.5258789e-04, -6.1035156e-05, -9.1552734e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MFWK0/SX349.WAV',
#   'array': array([-6.1035156e-05,  1.2207031e-04,  1.2207031e-04, ...,
#           1.2207031e-04, -3.0517578e-05,  2.7465820e-04], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MFWK0/SA1.WAV',
#   'array': array([-4.5776367e-04,  1.5258789e-04, -6.1035156e-05, ...,
#          -9.1552734e-05, -9.1552734e-05, -6.1035156e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MFWK0/SX79.WAV',
#   'array': array([ 2.1362305e-04, -3.0517578e-05,  6.1035156e-05, ...,
#           6.1035156e-05,  3.0517578e-05, -9.1552734e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MFWK0/SX169.WAV',
#   'array': array([ 3.9672852e-04, -9.1552734e-05,  6.1035156e-05, ...,
#           0.0000000e+00, -6.1035156e-05,  4.2724609e-04], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MFWK0/SI1879.WAV',
#   'array': array([ 4.5776367e-04, -2.1362305e-04,  6.1035156e-05, ...,
#           9.1552734e-05,  0.0000000e+00,  1.8310547e-04], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MFWK0/SI1249.WAV',
#   'array': array([-2.4414062e-04,  6.1035156e-05, -6.1035156e-05, ...,
#          -3.0517578e-05, -6.1035156e-05, -9.1552734e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MKAM0/SI1250.WAV',
#   'array': array([ 2.7465820e-04, -2.1362305e-04,  9.1552734e-05, ...,
#           3.3569336e-04,  2.1362305e-04,  3.3569336e-04], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MKAM0/SX416.WAV',
#   'array': array([-1.5258789e-04,  2.1362305e-04,  0.0000000e+00, ...,
#           6.1035156e-05,  6.1035156e-05,  6.1035156e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MKAM0/SA2.WAV',
#   'array': array([ 1.5258789e-04,  0.0000000e+00,  6.1035156e-05, ...,
#           1.2207031e-04,  9.1552734e-05, -6.1035156e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MKAM0/SA1.WAV',
#   'array': array([-2.4414062e-04,  2.4414062e-04,  3.3569336e-04, ...,
#          -6.1035156e-05, -3.0517578e-05,  6.1035156e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MKAM0/SX146.WAV',
#   'array': array([-2.4414062e-04,  1.8310547e-04, -1.5258789e-04, ...,
#           1.2207031e-04,  6.1035156e-05,  0.0000000e+00], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MKAM0/SX56.WAV',
#   'array': array([ 0.0000000e+00, -3.0517578e-05, -3.0517578e-05, ...,
#           3.0517578e-05,  3.0517578e-05, -6.1035156e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MKAM0/SX236.WAV',
#   'array': array([ 3.3569336e-04, -1.8310547e-04, -9.1552734e-05, ...,
#           0.0000000e+00,  6.1035156e-05,  0.0000000e+00], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MKAM0/SX326.WAV',
#   'array': array([ 3.9672852e-04,  2.4414062e-04, -6.1035156e-05, ...,
#           3.0517578e-05,  3.0517578e-05,  6.1035156e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MKAM0/SI1316.WAV',
#   'array': array([ 6.1035156e-05,  9.1552734e-05,  9.1552734e-05, ...,
#          -3.0517578e-05, -1.2207031e-04, -1.2207031e-04], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MKAM0/SI1465.WAV',
#   'array': array([ 2.1362305e-04, -1.5258789e-04,  6.1035156e-05, ...,
#           3.0517578e-05,  3.0517578e-05,  6.1035156e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MSMS0/SX263.WAV',
#   'array': array([-2.4414062e-04,  1.2207031e-04, -3.0517578e-05, ...,
#           3.0517578e-05,  9.1552734e-05,  3.0517578e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MSMS0/SI2063.WAV',
#   'array': array([-1.8310547e-04, -1.2207031e-04, -3.0517578e-05, ...,
#          -3.3569336e-04, -7.6293945e-04, -6.7138672e-04], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MSMS0/SI803.WAV',
#   'array': array([-2.4414062e-04,  0.0000000e+00,  3.0517578e-05, ...,
#          -6.1035156e-05,  2.7465820e-04,  3.3569336e-04], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MSMS0/SX173.WAV',
#   'array': array([-1.2207031e-04,  1.5258789e-04,  9.1552734e-05, ...,
#           1.2207031e-04,  1.2207031e-04,  9.1552734e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MSMS0/SA2.WAV',
#   'array': array([ 0.00027466, -0.00012207,  0.        , ...,  0.00024414,
#           0.00012207, -0.00012207], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MSMS0/SA1.WAV',
#   'array': array([-3.9672852e-04,  3.0517578e-05,  2.1362305e-04, ...,
#          -3.0517578e-05,  0.0000000e+00, -2.1362305e-04], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MSMS0/SI1433.WAV',
#   'array': array([ 1.2207031e-04, -9.1552734e-05, -1.2207031e-04, ...,
#          -6.1035156e-05,  3.0517578e-05,  0.0000000e+00], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MSMS0/SX353.WAV',
#   'array': array([9.1552734e-05, 1.2207031e-04, 9.1552734e-05, ..., 9.1552734e-05,
#          0.0000000e+00, 6.1035156e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MSMS0/SX83.WAV',
#   'array': array([-8.5449219e-04,  1.8310547e-04, -1.8310547e-04, ...,
#           3.0517578e-05,  0.0000000e+00, -3.0517578e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MSMS0/SX443.WAV',
#   'array': array([-6.1035156e-04,  2.7465820e-04, -1.5258789e-04, ...,
#           0.0000000e+00,  6.1035156e-05, -1.5258789e-04], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MGJC0/SI1335.WAV',
#   'array': array([-1.5869141e-03,  6.1035156e-04, -1.2207031e-04, ...,
#           9.1552734e-05, -3.0517578e-05, -1.2207031e-04], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MGJC0/SI1256.WAV',
#   'array': array([ 3.0517578e-05,  3.0517578e-05,  1.2207031e-04, ...,
#          -9.1552734e-05, -3.0517578e-05, -9.1552734e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MGJC0/SX165.WAV',
#   'array': array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, ..., 0.0000000e+00,
#          9.1552734e-05, 6.1035156e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MGJC0/SI1965.WAV',
#   'array': array([-2.7465820e-04,  0.0000000e+00,  0.0000000e+00, ...,
#          -3.0517578e-05, -6.1035156e-05, -9.1552734e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MGJC0/SA2.WAV',
#   'array': array([-6.1035156e-05,  1.2207031e-04,  0.0000000e+00, ...,
#           3.0517578e-05,  6.1035156e-05,  3.0517578e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MGJC0/SA1.WAV',
#   'array': array([ 2.4414062e-04, -1.5258789e-04,  3.0517578e-05, ...,
#          -6.1035156e-05, -3.0517578e-05, -1.5258789e-04], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MGJC0/SX75.WAV',
#   'array': array([ 9.1552734e-05, -9.1552734e-05, -3.0517578e-05, ...,
#           6.1035156e-05,  9.1552734e-05, -6.1035156e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MGJC0/SX345.WAV',
#   'array': array([-2.7465820e-04,  1.8310547e-04,  3.0517578e-05, ...,
#          -6.1035156e-05, -3.0517578e-05,  0.0000000e+00], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MGJC0/SX435.WAV',
#   'array': array([ 1.5258789e-04, -1.5258789e-04,  0.0000000e+00, ...,
#           0.0000000e+00,  9.1552734e-05,  0.0000000e+00], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MGJC0/SX255.WAV',
#   'array': array([ 3.3569336e-04, -9.1552734e-05,  6.1035156e-05, ...,
#           0.0000000e+00,  6.1035156e-05,  1.5258789e-04], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/FLKM0/SI686.WAV',
#   'array': array([ 3.0517578e-05,  0.0000000e+00, -6.1035156e-05, ...,
#          -2.1362305e-04,  6.1035156e-05, -1.2207031e-04], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/FLKM0/SX260.WAV',
#   'array': array([-6.1035156e-05,  6.1035156e-05,  3.0517578e-05, ...,
#          -6.1035156e-05, -6.1035156e-05, -1.2207031e-04], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/FLKM0/SX116.WAV',
#   'array': array([-3.6621094e-04, -2.7465820e-04, -9.1552734e-05, ...,
#           3.0517578e-05,  6.1035156e-05,  3.0517578e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/FLKM0/SA2.WAV',
#   'array': array([ 5.4931641e-04, -2.1362305e-04,  0.0000000e+00, ...,
#          -6.1035156e-05, -3.0517578e-05,  0.0000000e+00], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/FLKM0/SI620.WAV',
#   'array': array([ 9.1552734e-05,  9.1552734e-05,  3.0517578e-05, ...,
#          -3.0517578e-05,  0.0000000e+00,  9.1552734e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/FLKM0/SA1.WAV',
#   'array': array([-5.1879883e-04,  1.2207031e-04, -6.1035156e-05, ...,
#           1.5258789e-04,  6.1035156e-05,  6.1035156e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/FLKM0/SX350.WAV',
#   'array': array([-3.0517578e-04,  1.8310547e-04,  3.0517578e-05, ...,
#           9.1552734e-05, -3.0517578e-05,  2.4414062e-04], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/FLKM0/SX80.WAV',
#   'array': array([ 2.3193359e-03, -7.9345703e-04,  2.7465820e-04, ...,
#           1.8310547e-04,  1.5258789e-04,  3.0517578e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/FLKM0/SX440.WAV',
#   'array': array([-1.8310547e-04,  1.2207031e-04,  3.0517578e-05, ...,
#           3.0517578e-04,  2.1362305e-04, -1.8310547e-04], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/FLKM0/SI1880.WAV',
#   'array': array([ 6.1035156e-05, -1.8310547e-04, -3.9672852e-04, ...,
#           6.1035156e-05,  3.0517578e-05,  1.5258789e-04], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MMGC0/SX315.WAV',
#   'array': array([-9.1552734e-05,  1.2207031e-04, -3.0517578e-05, ...,
#           0.0000000e+00,  3.0517578e-05,  3.0517578e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MMGC0/SA2.WAV',
#   'array': array([-0.00106812,  0.00027466, -0.00018311, ...,  0.00033569,
#           0.00036621,  0.00021362], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MMGC0/SX405.WAV',
#   'array': array([-2.7465820e-04, -3.0517578e-05, -3.0517578e-05, ...,
#           0.0000000e+00, -3.0517578e-05, -6.1035156e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MMGC0/SA1.WAV',
#   'array': array([ 6.1035156e-05,  3.0517578e-05,  1.2207031e-04, ...,
#           6.1035156e-05, -6.1035156e-05,  6.1035156e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MMGC0/SX225.WAV',
#   'array': array([-1.8310547e-04,  9.1552734e-05, -9.1552734e-05, ...,
#           3.0517578e-05,  9.1552734e-05, -2.4414062e-04], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MMGC0/SX45.WAV',
#   'array': array([-9.1552734e-05,  4.2724609e-04,  3.3569336e-04, ...,
#           6.1035156e-05,  0.0000000e+00,  9.1552734e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MMGC0/SI1305.WAV',
#   'array': array([-3.0517578e-04, -3.3569336e-04, -3.0517578e-04, ...,
#           9.1552734e-05,  3.0517578e-05,  1.2207031e-04], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MMGC0/SI2184.WAV',
#   'array': array([-5.7983398e-04, -3.0517578e-05, -2.7465820e-04, ...,
#           0.0000000e+00, -9.1552734e-05, -1.2207031e-04], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MMGC0/SX135.WAV',
#   'array': array([-0.00064087,  0.00054932,  0.00015259, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MMGC0/SI1935.WAV',
#   'array': array([ 1.8310547e-04, -2.1362305e-04,  2.1362305e-04, ...,
#           0.0000000e+00, -3.0517578e-05,  6.1035156e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MJXL0/SX272.WAV',
#   'array': array([-3.6621094e-04, -4.8828125e-04, -6.1035156e-04, ...,
#           6.1035156e-05,  3.0517578e-05, -2.7465820e-04], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MJXL0/SI1795.WAV',
#   'array': array([ 1.5258789e-04, -6.1035156e-05,  6.1035156e-05, ...,
#          -1.2207031e-04, -9.1552734e-05,  9.1552734e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MJXL0/SX362.WAV',
#   'array': array([-1.5258789e-04,  1.5258789e-04,  0.0000000e+00, ...,
#           3.0517578e-05,  0.0000000e+00,  1.2207031e-04], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MJXL0/SA2.WAV',
#   'array': array([-9.1552734e-05,  9.1552734e-05,  0.0000000e+00, ...,
#          -1.2207031e-04, -1.8310547e-04, -6.1035156e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MJXL0/SI542.WAV',
#   'array': array([6.1035156e-05, 1.2207031e-04, 3.0517578e-05, ..., 3.0517578e-05,
#          0.0000000e+00, 3.0517578e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MJXL0/SA1.WAV',
#   'array': array([ 4.5776367e-04,  0.0000000e+00, -1.8310547e-04, ...,
#           6.1035156e-05, -9.1552734e-05, -3.0517578e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MJXL0/SI1172.WAV',
#   'array': array([ 3.9672852e-04, -1.2207031e-04,  3.0517578e-05, ...,
#          -6.1035156e-05, -3.0517578e-05, -6.1035156e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MJXL0/SX92.WAV',
#   'array': array([9.1552734e-05, 6.1035156e-05, 1.2207031e-04, ..., 9.1552734e-05,
#          1.2207031e-04, 9.1552734e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MJXL0/SX182.WAV',
#   'array': array([-3.0517578e-05,  0.0000000e+00,  0.0000000e+00, ...,
#          -1.8310547e-04, -9.1552734e-05, -9.1552734e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MJXL0/SX452.WAV',
#   'array': array([-3.6621094e-04,  9.1552734e-05, -6.1035156e-05, ...,
#           3.0517578e-05,  3.0517578e-05,  0.0000000e+00], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MMBS0/SI521.WAV',
#   'array': array([-1.2207031e-04,  2.4414062e-04,  3.0517578e-05, ...,
#           1.2207031e-04,  6.1035156e-05,  9.1552734e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MMBS0/SX71.WAV',
#   'array': array([ 1.2207031e-04, -2.7465820e-04, -3.0517578e-05, ...,
#           3.0517578e-04,  3.0517578e-04,  9.1552734e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MMBS0/SI1781.WAV',
#   'array': array([ 1.0681152e-03,  1.5258789e-04,  4.5776367e-04, ...,
#          -6.1035156e-05, -6.1035156e-05,  0.0000000e+00], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MMBS0/SI1151.WAV',
#   'array': array([1.2207031e-04, 0.0000000e+00, 3.0517578e-05, ..., 2.1362305e-04,
#          2.1362305e-04, 9.1552734e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MMBS0/SA2.WAV',
#   'array': array([-1.2207031e-04, -2.7465820e-04, -2.1362305e-04, ...,
#           0.0000000e+00, -6.1035156e-05,  1.2207031e-04], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MMBS0/SX161.WAV',
#   'array': array([4.5776367e-04, 6.1035156e-04, 2.4414062e-04, ..., 9.1552734e-05,
#          0.0000000e+00, 3.0517578e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MMBS0/SA1.WAV',
#   'array': array([1.8310547e-04, 0.0000000e+00, 3.0517578e-05, ..., 3.6621094e-04,
#          9.1552734e-05, 9.7656250e-04], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MMBS0/SX431.WAV',
#   'array': array([ 1.2512207e-03,  3.3569336e-04, -2.1362305e-04, ...,
#           3.0517578e-05,  3.0517578e-05,  6.1035156e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MMBS0/SX341.WAV',
#   'array': array([ 6.1035156e-05, -3.0517578e-05,  3.0517578e-05, ...,
#           6.1035156e-05, -3.0517578e-05,  2.7465820e-04], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MMBS0/SX251.WAV',
#   'array': array([-8.5449219e-04, -3.0517578e-05, -2.4414062e-04, ...,
#           9.1552734e-05,  6.1035156e-05,  0.0000000e+00], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MTQC0/SI1441.WAV',
#   'array': array([ 3.3569336e-04, -9.1552734e-05,  3.0517578e-05, ...,
#           4.8828125e-04,  1.2207031e-04,  6.1035156e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MTQC0/SX271.WAV',
#   'array': array([ 9.1552734e-05,  0.0000000e+00,  1.5258789e-04, ...,
#           3.0517578e-05, -9.1552734e-05,  2.7465820e-04], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MTQC0/SI480.WAV',
#   'array': array([-6.1035156e-05,  6.1035156e-05,  2.1362305e-04, ...,
#           4.8828125e-04,  3.0517578e-04,  3.3569336e-04], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MTQC0/SI2071.WAV',
#   'array': array([ 3.6621094e-04, -3.0517578e-05, -1.8310547e-04, ...,
#           0.0000000e+00, -3.0517578e-05, -9.1552734e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MTQC0/SA2.WAV',
#   'array': array([ 7.3242188e-04, -2.4414062e-04,  6.1035156e-05, ...,
#          -1.5258789e-04, -9.1552734e-05,  0.0000000e+00], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MTQC0/SX361.WAV',
#   'array': array([-3.9672852e-04,  9.1552734e-05,  0.0000000e+00, ...,
#          -6.1035156e-05, -3.0517578e-05,  0.0000000e+00], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MTQC0/SA1.WAV',
#   'array': array([ 1.8310547e-04, -9.1552734e-05,  9.1552734e-05, ...,
#           6.1035156e-05, -3.9672852e-04, -2.7465820e-04], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MTQC0/SX91.WAV',
#   'array': array([-3.9672852e-04,  9.1552734e-05, -3.0517578e-05, ...,
#           3.0517578e-05,  9.1552734e-05,  1.2207031e-04], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MTQC0/SX181.WAV',
#   'array': array([ 1.5258789e-04, -9.1552734e-05, -6.1035156e-05, ...,
#           0.0000000e+00,  6.1035156e-05,  3.0517578e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MTQC0/SX451.WAV',
#   'array': array([-1.5258789e-04,  4.5776367e-04,  3.0517578e-04, ...,
#           3.0517578e-05,  3.0517578e-05,  3.0517578e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MBWP0/SX259.WAV',
#   'array': array([3.0517578e-04, 6.1035156e-05, 6.1035156e-05, ..., 9.1552734e-05,
#          6.1035156e-05, 0.0000000e+00], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR4/MBWP0/SI709.WAV',
#   'array': array([-2.4414062e-04, -2.4414062e-04, -3.0517578e-05, ...,
#          -3.0517578e-05,  3.0517578e-05, -6.1035156e-05], dtype=float32),
# ...
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR3/MDLC0/SI1395.WAV',
#   'array': array([-3.0517578e-04,  1.8310547e-04, -9.1552734e-05, ...,
#           0.0000000e+00,  6.1035156e-05,  3.0517578e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR3/MDLC0/SA1.WAV',
#   'array': array([0.0000000e+00, 3.0517578e-05, 0.0000000e+00, ..., 6.1035156e-05,
#          6.1035156e-05, 1.5258789e-04], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR3/MDLC0/SX225.WAV',
#   'array': array([-1.2817383e-03,  3.9672852e-04, -2.4414062e-04, ...,
#          -9.1552734e-05,  0.0000000e+00,  2.4414062e-04], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR3/MDLC0/SI765.WAV',
#   'array': array([ 3.0517578e-05,  9.1552734e-05,  9.1552734e-05, ...,
#          -9.1552734e-05, -6.1035156e-05,  0.0000000e+00], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR3/MDLC0/SX45.WAV',
#   'array': array([ 2.7465820e-04,  3.0517578e-05,  9.1552734e-05, ...,
#          -2.7465820e-04,  0.0000000e+00, -2.1362305e-04], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR3/MDLC0/SX135.WAV',
#   'array': array([ 0.0000000e+00,  0.0000000e+00, -3.0517578e-05, ...,
#           6.1035156e-05,  6.1035156e-05,  6.1035156e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR3/MDLC0/SI2025.WAV',
#   'array': array([ 1.8310547e-04, -6.1035156e-05,  1.5258789e-04, ...,
#           6.1035156e-05, -3.0517578e-05,  1.5258789e-04], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR3/MBEF0/SX111.WAV',
#   'array': array([-5.1879883e-04,  1.5258789e-04,  0.0000000e+00, ...,
#           9.1552734e-05,  0.0000000e+00, -6.1035156e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR3/MBEF0/SI1911.WAV',
#   'array': array([ 2.4414062e-04, -3.0517578e-05,  3.0517578e-05, ...,
#           3.0517578e-05, -6.1035156e-05,  0.0000000e+00], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR3/MBEF0/SI651.WAV',
#   'array': array([ 3.0517578e-05,  3.0517578e-05, -3.0517578e-05, ...,
#           1.5258789e-04,  3.0517578e-05,  1.2207031e-04], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR3/MBEF0/SI1281.WAV',
#   'array': array([ 2.4414062e-04, -3.0517578e-05,  1.5258789e-04, ...,
#           6.1035156e-05,  6.1035156e-05, -3.0517578e-04], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR3/MBEF0/SA2.WAV',
#   'array': array([ 3.0517578e-04, -9.1552734e-05,  6.1035156e-05, ...,
#           6.1035156e-05, -6.1035156e-05, -6.1035156e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR3/MBEF0/SX201.WAV',
#   'array': array([ 3.9672852e-04, -3.0517578e-05,  9.1552734e-05, ...,
#           2.4414062e-04,  1.2207031e-04, -1.5258789e-04], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR3/MBEF0/SA1.WAV',
#   'array': array([ 3.0517578e-04, -3.0517578e-05,  1.8310547e-04, ...,
#           2.4414062e-04,  9.1552734e-05,  3.0517578e-04], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR3/MBEF0/SX381.WAV',
#   'array': array([-2.4414062e-04,  9.1552734e-05, -3.0517578e-05, ...,
#           0.0000000e+00, -1.5258789e-04, -1.5258789e-04], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR3/MBEF0/SX291.WAV',
#   'array': array([-1.2207031e-04,  1.2207031e-04,  6.1035156e-05, ...,
#           0.0000000e+00,  6.1035156e-05,  6.1035156e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR3/MBEF0/SX21.WAV',
#   'array': array([-4.5776367e-04, -3.0517578e-05, -2.7465820e-04, ...,
#          -6.1035156e-05,  1.2207031e-04,  9.1552734e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR3/MRDS0/SX267.WAV',
#   'array': array([ 3.0517578e-04, -9.1552734e-05,  0.0000000e+00, ...,
#           6.1035156e-05, -1.5258789e-04,  3.0517578e-04], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR3/MRDS0/SI537.WAV',
#   'array': array([-1.2207031e-04,  3.0517578e-05,  6.1035156e-05, ...,
#          -9.1552734e-05, -9.1552734e-05,  0.0000000e+00], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR3/MRDS0/SI1797.WAV',
#   'array': array([-1.8005371e-03,  3.6621094e-04, -3.3569336e-04, ...,
#          -6.1035156e-05,  3.0517578e-05, -2.1362305e-04], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR3/MRDS0/SA2.WAV',
#   'array': array([-1.5258789e-04,  1.8310547e-04,  3.0517578e-05, ...,
#           5.7983398e-04,  8.5449219e-04,  6.4086914e-04], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR3/MRDS0/SX177.WAV',
#   'array': array([-3.0517578e-05,  0.0000000e+00,  6.1035156e-05, ...,
#           0.0000000e+00,  1.2207031e-04,  2.4414062e-04], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR3/MRDS0/SA1.WAV',
#   'array': array([-2.7465820e-04,  9.1552734e-05, -3.0517578e-05, ...,
#           9.1552734e-05,  3.0517578e-05, -3.0517578e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR3/MRDS0/SX87.WAV',
#   'array': array([ 0.        ,  0.00018311,  0.00036621, ..., -0.00039673,
#          -0.00030518,  0.00015259], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR3/MRDS0/SI1167.WAV',
#   'array': array([ 6.4086914e-04, -1.5258789e-04,  3.0517578e-05, ...,
#          -3.0517578e-05,  2.4414062e-04, -3.0517578e-04], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR3/MRDS0/SX357.WAV',
#   'array': array([-3.0517578e-04,  2.4414062e-04,  0.0000000e+00, ...,
#           1.2207031e-04,  6.1035156e-05, -3.0517578e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR3/MRDS0/SX447.WAV',
#   'array': array([-0.00079346,  0.00024414,  0.00018311, ..., -0.00015259,
#          -0.00012207, -0.00015259], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR3/MGAF0/SI652.WAV',
#   'array': array([-1.5258789e-04,  1.8310547e-04,  6.1035156e-05, ...,
#          -3.0517578e-05, -6.1035156e-05, -1.2207031e-04], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR3/MGAF0/SX112.WAV',
#   'array': array([-2.7465820e-04,  1.8310547e-04,  3.0517578e-05, ...,
#          -9.1552734e-05,  9.1552734e-05,  3.0517578e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR3/MGAF0/SI1912.WAV',
#   'array': array([-5.4931641e-04,  1.8310547e-04,  0.0000000e+00, ...,
#           0.0000000e+00, -3.0517578e-05, -9.1552734e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR3/MGAF0/SI1282.WAV',
#   'array': array([-6.1035156e-05,  1.2207031e-04, -3.0517578e-05, ...,
#           6.1035156e-05, -3.0517578e-05,  2.4414062e-04], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR3/MGAF0/SX202.WAV',
#   'array': array([-1.2207031e-04,  1.2207031e-04, -3.0517578e-05, ...,
#           1.8310547e-04,  3.0517578e-04,  2.7465820e-04], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR3/MGAF0/SA2.WAV',
#   'array': array([ 5.4931641e-04, -2.4414062e-04,  6.1035156e-05, ...,
#           6.1035156e-05,  9.1552734e-05,  3.0517578e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR3/MGAF0/SA1.WAV',
#   'array': array([-5.7983398e-04,  2.4414062e-04, -6.1035156e-05, ...,
#           3.0517578e-05, -6.1035156e-05,  2.1362305e-04], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR3/MGAF0/SX382.WAV',
#   'array': array([-1.2207031e-04,  0.0000000e+00, -6.1035156e-05, ...,
#           3.0517578e-05, -6.1035156e-05,  2.1362305e-04], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR3/MGAF0/SX292.WAV',
#   'array': array([ 3.0517578e-04, -1.2207031e-04,  9.1552734e-05, ...,
#          -6.1035156e-05,  3.0517578e-05, -3.0517578e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR3/MGAF0/SX22.WAV',
#   'array': array([-4.5776367e-04,  9.1552734e-05, -1.2207031e-04, ...,
#           0.0000000e+00,  3.0517578e-05,  1.2207031e-04], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR3/MJLG1/SI1642.WAV',
#   'array': array([ 4.5776367e-04,  3.0517578e-04,  1.5258789e-04, ...,
#          -3.0517578e-05, -4.8828125e-04, -3.0517578e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR3/MJLG1/SX112.WAV',
#   'array': array([ 9.1552734e-05, -3.0517578e-05,  0.0000000e+00, ...,
#           9.1552734e-05,  1.2207031e-04,  3.0517578e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR3/MJLG1/SI2272.WAV',
#   'array': array([6.1035156e-05, 9.1552734e-05, 3.0517578e-05, ..., 1.2207031e-04,
#          9.1552734e-05, 1.5258789e-04], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR3/MJLG1/SX202.WAV',
#   'array': array([-1.5258789e-04, -3.3569336e-04, -1.8310547e-04, ...,
#           6.1035156e-05,  9.1552734e-05, -1.2207031e-04], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR3/MJLG1/SA2.WAV',
#   'array': array([ 3.0517578e-05,  1.5258789e-04, -3.0517578e-05, ...,
#          -1.2207031e-04, -1.2207031e-04, -1.2207031e-04], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR3/MJLG1/SA1.WAV',
#   'array': array([1.2207031e-04, 1.2207031e-04, 9.1552734e-05, ..., 2.1362305e-04,
#          3.0517578e-05, 0.0000000e+00], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR3/MJLG1/SI1012.WAV',
#   'array': array([1.5258789e-04, 0.0000000e+00, 3.0517578e-05, ..., 9.1552734e-05,
#          0.0000000e+00, 6.1035156e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR3/MJLG1/SX382.WAV',
#   'array': array([-4.5776367e-04, -4.2724609e-04, -2.1362305e-04, ...,
#          -1.8310547e-04, -2.1362305e-04, -9.1552734e-05], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR3/MJLG1/SX292.WAV',
#   'array': array([ 0.0000000e+00, -3.0517578e-05,  0.0000000e+00, ...,
#           6.1035156e-05,  1.2207031e-04,  0.0000000e+00], dtype=float32),
#   'sampling_rate': 16000},
#  {'path': '/Users/mac/.cache/huggingface/datasets/downloads/extracted/86096937f792a33c316ac9ea43f48d3dc40aac8eb909880575f0f2eb2fc29ded/data/TRAIN/DR3/MJLG1/SX22.WAV',
#   'array': array([-1.8310547e-04, -4.2724609e-04, -3.3569336e-04, ...,
#           9.1552734e-05,  3.0517578e-05,  0.0000000e+00], dtype=float32),
#   'sampling_rate': 16000},
#  ...]

# %%
import IPython.display as ipd
import numpy as np
import random

rand_int = random.randint(0, len(timit["train"]))

print(timit["train"][rand_int]["text"])
ipd.Audio(data=np.asarray(timit["train"][rand_int]["audio"]["array"]), autoplay=True, rate=16000)
# Out:
# the courier was a dwarf
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
rand_int = random.randint(0, len(timit["train"]))

print("Target text:", timit["train"][rand_int]["text"])
print("Input array shape:", np.asarray(timit["train"][rand_int]["audio"]["array"]).shape)
print("Sampling rate:", timit["train"][rand_int]["audio"]["sampling_rate"])
# Out:
# Target text: his scalp was blistered from today's hot sun
# Input array shape: (47207,)
# Sampling rate: 16000

# %%
def prepare_dataset(batch):
    audio = batch["audio"]

    # batched output is "un-batched" to ensure mapping is correct
    batch["input_values"] = processor(audio["array"], sampling_rate=audio["sampling_rate"]).input_values[0]
    
    with processor.as_target_processor():
        batch["labels"] = processor(batch["text"]).input_ids
    return batch

# %%
import numpy as np
np.object = object 
timit = timit.map(prepare_dataset, remove_columns=timit.column_names["train"], num_proc=4)

# %%
import torch

from dataclasses import dataclass, field
from typing import Any, Dict, List, Optional, Union

@dataclass
class DataCollatorCTCWithPadding:
    """
    Data collator that will dynamically pad the inputs received.
    Args:
        processor (:class:`~transformers.Wav2Vec2Processor`)
            The processor used for proccessing the data.
        padding (:obj:`bool`, :obj:`str` or :class:`~transformers.tokenization_utils_base.PaddingStrategy`, `optional`, defaults to :obj:`True`):
            Select a strategy to pad the returned sequences (according to the model's padding side and padding index)
            among:
            * :obj:`True` or :obj:`'longest'`: Pad to the longest sequence in the batch (or no padding if only a single
              sequence if provided).
            * :obj:`'max_length'`: Pad to a maximum length specified with the argument :obj:`max_length` or to the
              maximum acceptable input length for the model if that argument is not provided.
            * :obj:`False` or :obj:`'do_not_pad'` (default): No padding (i.e., can output a batch with sequences of
              different lengths).
        max_length (:obj:`int`, `optional`):
            Maximum length of the ``input_values`` of the returned list and optionally padding length (see above).
        max_length_labels (:obj:`int`, `optional`):
            Maximum length of the ``labels`` returned list and optionally padding length (see above).
        pad_to_multiple_of (:obj:`int`, `optional`):
            If set will pad the sequence to a multiple of the provided value.
            This is especially useful to enable the use of Tensor Cores on NVIDIA hardware with compute capability >=
            7.5 (Volta).
    """

    processor: Wav2Vec2Processor
    padding: Union[bool, str] = True
    max_length: Optional[int] = None
    max_length_labels: Optional[int] = None
    pad_to_multiple_of: Optional[int] = None
    pad_to_multiple_of_labels: Optional[int] = None

    def __call__(self, features: List[Dict[str, Union[List[int], torch.Tensor]]]) -> Dict[str, torch.Tensor]:
        # split inputs and labels since they have to be of different lengths and need
        # different padding methods
        input_features = [{"input_values": feature["input_values"]} for feature in features]
        label_features = [{"input_ids": feature["labels"]} for feature in features]

        batch = self.processor.pad(
            input_features,
            padding=self.padding,
            max_length=self.max_length,
            pad_to_multiple_of=self.pad_to_multiple_of,
            return_tensors="pt",
        )
        with self.processor.as_target_processor():
            labels_batch = self.processor.pad(
                label_features,
                padding=self.padding,
                max_length=self.max_length_labels,
                pad_to_multiple_of=self.pad_to_multiple_of_labels,
                return_tensors="pt",
            )

        # replace padding with -100 to ignore loss correctly
        labels = labels_batch["input_ids"].masked_fill(labels_batch.attention_mask.ne(1), -100)

        batch["labels"] = labels

        return batch

# %%
data_collator = DataCollatorCTCWithPadding(processor=processor, padding=True)

# %%
wer_metric = load_metric("wer")

# %%
def compute_metrics(pred):
    pred_logits = pred.predictions
    pred_ids = np.argmax(pred_logits, axis=-1)

    pred.label_ids[pred.label_ids == -100] = processor.tokenizer.pad_token_id

    pred_str = processor.batch_decode(pred_ids)
    # we do not want to group tokens when computing the metrics
    label_str = processor.batch_decode(pred.label_ids, group_tokens=False)

    wer = wer_metric.compute(predictions=pred_str, references=label_str)

    return {"wer": wer}

# %%
from transformers import Wav2Vec2ForCTC

model = Wav2Vec2ForCTC.from_pretrained(
    "facebook/wav2vec2-base", 
    ctc_loss_reduction="mean", 
    pad_token_id=processor.tokenizer.pad_token_id,
)
# Out:
# /Users/mac/anaconda3/lib/python3.11/site-packages/transformers/configuration_utils.py:356: UserWarning: Passing `gradient_checkpointing` to a config initialization is deprecated and will be removed in v5 Transformers. Using `model.gradient_checkpointing_enable()` instead, or if you are using the `Trainer` API, pass `gradient_checkpointing=True` in your `TrainingArguments`.
#   warnings.warn(
# /Users/mac/anaconda3/lib/python3.11/site-packages/torch/nn/utils/weight_norm.py:28: UserWarning: torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.
#   warnings.warn("torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.")
# Some weights of the model checkpoint at facebook/wav2vec2-base were not used when initializing Wav2Vec2ForCTC: ['project_hid.weight', 'project_hid.bias', 'quantizer.weight_proj.bias', 'quantizer.weight_proj.weight', 'quantizer.codevectors', 'project_q.bias', 'project_q.weight']
# - This IS expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at facebook/wav2vec2-base and are newly initialized: ['lm_head.weight', 'lm_head.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
model.freeze_feature_extractor()
# Out:
# /Users/mac/anaconda3/lib/python3.11/site-packages/transformers/models/wav2vec2/modeling_wav2vec2.py:1709: FutureWarning: The method `freeze_feature_extractor` is deprecated and will be removed in Transformers v5.Please use the equivalent `freeze_feature_encoder` method instead.
#   warnings.warn(

# %%
from transformers import TrainingArguments

training_args = TrainingArguments(
  output_dir=repo_name,
  group_by_length=True,
  per_device_train_batch_size=32,
  evaluation_strategy="steps",
  num_train_epochs=30,
  fp16=True,
  gradient_checkpointing=True, 
  save_steps=500,
  eval_steps=500,
  logging_steps=500,
  learning_rate=1e-4,
  weight_decay=0.005,
  warmup_steps=1000,
  save_total_limit=2,
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 from transformers import TrainingArguments
#       3 training_args = TrainingArguments(
# ----> 4   output_dir=repo_name,
#       5   group_by_length=True,
#       6   per_device_train_batch_size=32,
#       7   evaluation_strategy="steps",
#       8   num_train_epochs=30,
#       9   fp16=True,
#      10   gradient_checkpointing=True,
#      11   save_steps=500,
#      12   eval_steps=500,
#      13   logging_steps=500,
#      14   learning_rate=1e-4,
#      15   weight_decay=0.005,
#      16   warmup_steps=1000,
#      17   save_total_limit=2,
#      18 )
#
# NameError: name 'repo_name' is not defined
