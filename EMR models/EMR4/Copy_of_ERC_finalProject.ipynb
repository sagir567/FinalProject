# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import librosa
import librosa.display
import torchaudio
import torch
import tensorflow as tf
import warnings
warnings.filterwarnings('ignore')

# to play the audio files
from IPython.display import Audio
from keras.callbacks import ModelCheckpoint
from keras.callbacks import LearningRateScheduler
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from collections.abc import Iterable
from sklearn.preprocessing import OneHotEncoder
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, BatchNormalization
from keras import layers, callbacks
from IPython.display import Audio
from torch.utils.data import Dataset, DataLoader
from transformers import Wav2Vec2Model, Wav2Vec2Processor, Trainer, TrainingArguments, Wav2Vec2ForSequenceClassification

# %%
# Crema_path = Root_dir + "/Crema/"
# Ravdess_path = Root_dir + "/Ravdess/audio_speech_actors_01-24/"
# Savee_path = Root_dir + "/Savee/"
# Tess_path = Root_dir + "/Tess/"
# print(Crema_path ,"\n")
# print(Ravdess_path,"\n")
# print(Savee_path,"\n")
# print(Tess_path,"\n")

# Download latest version
import kagglehub
path = kagglehub.dataset_download("dmitrybabko/speech-emotion-recognition-en")

print("Path to dataset files:", path)



paths = []
labels = []
for dirname, _, filenames in os.walk(path):
    for filename in filenames:
        paths.append(os.path.join(dirname, filename))
        label = filename.split('_')[-1]
        label = label.split('.')[0]
        labels.append(label.lower())
    if len(paths) == 2800:
        break
print('Dataset is Loaded')

print('Dataset is Loaded')
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/dmitrybabko/speech-emotion-recognition-en?dataset_version_number=1...
# 100%|██████████| 987M/987M [00:06<00:00, 167MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/dmitrybabko/speech-emotion-recognition-en/versions/1
# Dataset is Loaded
# Dataset is Loaded

# %%
root_dir = path

Crema_path = root_dir + "/Crema/"
Ravdess_path = root_dir + "/Ravdess/audio_speech_actors_01-24/"
Savee_path = root_dir + "/Savee/"
Tess_path = root_dir + "/Tess/"
print(Tess_path,"\n")
print(Savee_path,"\n")
print(Ravdess_path,"\n")
print(Crema_path,"\n")
# Out:
# /root/.cache/kagglehub/datasets/dmitrybabko/speech-emotion-recognition-en/versions/1/Tess/
#
# /root/.cache/kagglehub/datasets/dmitrybabko/speech-emotion-recognition-en/versions/1/Savee/
#
# /root/.cache/kagglehub/datasets/dmitrybabko/speech-emotion-recognition-en/versions/1/Ravdess/audio_speech_actors_01-24/
#
# /root/.cache/kagglehub/datasets/dmitrybabko/speech-emotion-recognition-en/versions/1/Crema/

# %%
Crema_dir_list = os.listdir(Crema_path)
Ravdess_dir_list = os.listdir(Ravdess_path)
Savee_dir_list = os.listdir(Savee_path)
Tess_dir_list = os.listdir(Tess_path)

# %%
Ex_Crema_dir_list = Crema_dir_list[:15]
Ex_Crema_dir_list
# Out:
# ['1074_IWW_DIS_XX.wav',
#  '1090_MTI_DIS_XX.wav',
#  '1046_IEO_HAP_LO.wav',
#  '1032_IWW_FEA_XX.wav',
#  '1084_IEO_DIS_LO.wav',
#  '1015_WSI_NEU_XX.wav',
#  '1051_IWL_ANG_XX.wav',
#  '1089_TAI_DIS_XX.wav',
#  '1006_IEO_SAD_LO.wav',
#  '1057_IEO_FEA_HI.wav',
#  '1085_DFA_DIS_XX.wav',
#  '1089_IEO_FEA_HI.wav',
#  '1009_DFA_HAP_XX.wav',
#  '1042_TAI_ANG_XX.wav',
#  '1066_TSI_SAD_XX.wav']

# %%
emotions_crema = []
paths_crema = []

for it in Crema_dir_list:
    # storing file paths
    paths_crema.append(Crema_path + it)
    # storing file emotions
    part = it.split('_')
    if part[2] == 'SAD':
        emotions_crema.append('sad')
    elif part[2] == 'ANG':
        emotions_crema.append('angry')
    elif part[2] == 'DIS':
        emotions_crema.append('disgust')
    elif part[2] == 'FEA':
        emotions_crema.append('fear')
    elif part[2] == 'HAP':
        emotions_crema.append('happy')
    elif part[2] == 'NEU':
        emotions_crema.append('neutral')
    else:
        emotions_crema.append('Unknown')

# dataframe for emotion of files
emotions_crema_df = pd.DataFrame(emotions_crema, columns=['Emotions'])

# dataframe for path of files.
path_crema_df = pd.DataFrame(paths_crema, columns=['Path'])
Crema_df = pd.concat([emotions_crema_df, path_crema_df], axis=1)
print(Crema_df.shape)
Crema_df.head().style.set_properties(**{'background-color': '#9490ff',
                           'color': 'black',
                           'border-color': 'black'})
# Out:
# (7442, 2)
# <style type="text/css">
# #T_d3850_row0_col0, #T_d3850_row0_col1, #T_d3850_row1_col0, #T_d3850_row1_col1, #T_d3850_row2_col0, #T_d3850_row2_col1, #T_d3850_row3_col0, #T_d3850_row3_col1, #T_d3850_row4_col0, #T_d3850_row4_col1 {
#   background-color: #9490ff;
#   color: black;
#   border-color: black;
# }
# </style>
# <table id="T_d3850" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d3850_level0_col0" class="col_heading level0 col0" >Emotions</th>
#       <th id="T_d3850_level0_col1" class="col_heading level0 col1" >Path</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d3850_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d3850_row0_col0" class="data row0 col0" >disgust</td>
#       <td id="T_d3850_row0_col1" class="data row0 col1" >/root/.cache/kagglehub/datasets/dmitrybabko/speech-emotion-recognition-en/versions/1/Crema/1074_IWW_DIS_XX.wav</td>
#     </tr>
#     <tr>
#       <th id="T_d3850_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d3850_row1_col0" class="data row1 col0" >disgust</td>
#       <td id="T_d3850_row1_col1" class="data row1 col1" >/root/.cache/kagglehub/datasets/dmitrybabko/speech-emotion-recognition-en/versions/1/Crema/1090_MTI_DIS_XX.wav</td>
#     </tr>
#     <tr>
#       <th id="T_d3850_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d3850_row2_col0" class="data row2 col0" >happy</td>
#       <td id="T_d3850_row2_col1" class="data row2 col1" >/root/.cache/kagglehub/datasets/dmitrybabko/speech-emotion-recognition-en/versions/1/Crema/1046_IEO_HAP_LO.wav</td>
#     </tr>
#     <tr>
#       <th id="T_d3850_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d3850_row3_col0" class="data row3 col0" >fear</td>
#       <td id="T_d3850_row3_col1" class="data row3 col1" >/root/.cache/kagglehub/datasets/dmitrybabko/speech-emotion-recognition-en/versions/1/Crema/1032_IWW_FEA_XX.wav</td>
#     </tr>
#     <tr>
#       <th id="T_d3850_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d3850_row4_col0" class="data row4 col0" >disgust</td>
#       <td id="T_d3850_row4_col1" class="data row4 col1" >/root/.cache/kagglehub/datasets/dmitrybabko/speech-emotion-recognition-en/versions/1/Crema/1084_IEO_DIS_LO.wav</td>
#     </tr>
#   </tbody>
# </table>

# %%
[Crema_df["Emotions"].unique().tolist() for i in Crema_df.columns]
# Out:
# [['disgust', 'happy', 'fear', 'neutral', 'angry', 'sad'],
#  ['disgust', 'happy', 'fear', 'neutral', 'angry', 'sad']]

# %%
font1 = {'family':'Times New Roman','color':'blue','size':30}
font2 = {'family':'Times New Roman','color':'blue','size':20}
font3 = {'family':'Times New Roman','color':'blue','size':10}

# %%
sns.set(style="whitegrid", color_codes=True)
plt.figure(figsize=(20,10),dpi=200)
Count_emotion = Crema_df['Emotions'].value_counts()[:]
ax = sns.barplot(x= Count_emotion, y= Count_emotion.index, palette="mako")
ax.bar_label(ax.containers[0],fontsize=16)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.ylabel("Name of Emotions", fontdict= font1)
plt.xlabel("Count of Emotions", fontdict= font1)
plt.title("Emotions - Count", fontdict= font1)
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.

# %%
Ex_Ravdess_dir_list = Ravdess_dir_list[:15]
Ex_Ravdess_dir_list
# Out:
# ['Actor_03',
#  'Actor_01',
#  'Actor_04',
#  'Actor_10',
#  'Actor_17',
#  'Actor_20',
#  'Actor_18',
#  'Actor_05',
#  'Actor_06',
#  'Actor_15',
#  'Actor_12',
#  'Actor_22',
#  'Actor_08',
#  'Actor_14',
#  'Actor_11']

# %%
emotions_ravdess = []
path_ravdess = []

for it in Ravdess_dir_list:
    # There are 20 actors
    actor = os.listdir(Ravdess_path + it)
    for file in actor:
        part = file.split('.')[0]
        part = part.split('-')
        # third part in each file represents the emotion associated to that file.
        emotions_ravdess.append(int(part[2]))
        path_ravdess.append(Ravdess_path + it + '/' + file)


emotion_ravdess_df = pd.DataFrame(emotions_ravdess, columns=['Emotions'])

path_ravdess_df = pd.DataFrame(path_ravdess, columns=['Path'])
Ravdess_df = pd.concat([emotion_ravdess_df, path_ravdess_df], axis=1)

# changing integers to actual emotions.
Ravdess_df.Emotions.replace({1:'neutral', 2:'calm',
                             3:'happy', 4:'sad', 5:'angry',
                             6:'fear', 7:'disgust', 8:'surprise'}, inplace=True)
Ravdess_df.head().style.set_properties(**{'background-color': '#9490ff',
                           'color': 'black',
                           'border-color': 'black'})
# Out:
# <style type="text/css">
# #T_03cbc_row0_col0, #T_03cbc_row0_col1, #T_03cbc_row1_col0, #T_03cbc_row1_col1, #T_03cbc_row2_col0, #T_03cbc_row2_col1, #T_03cbc_row3_col0, #T_03cbc_row3_col1, #T_03cbc_row4_col0, #T_03cbc_row4_col1 {
#   background-color: #9490ff;
#   color: black;
#   border-color: black;
# }
# </style>
# <table id="T_03cbc" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_03cbc_level0_col0" class="col_heading level0 col0" >Emotions</th>
#       <th id="T_03cbc_level0_col1" class="col_heading level0 col1" >Path</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_03cbc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_03cbc_row0_col0" class="data row0 col0" >calm</td>
#       <td id="T_03cbc_row0_col1" class="data row0 col1" >/root/.cache/kagglehub/datasets/dmitrybabko/speech-emotion-recognition-en/versions/1/Ravdess/audio_speech_actors_01-24/Actor_03/03-01-02-02-01-01-03.wav</td>
#     </tr>
#     <tr>
#       <th id="T_03cbc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_03cbc_row1_col0" class="data row1 col0" >fear</td>
#       <td id="T_03cbc_row1_col1" class="data row1 col1" >/root/.cache/kagglehub/datasets/dmitrybabko/speech-emotion-recognition-en/versions/1/Ravdess/audio_speech_actors_01-24/Actor_03/03-01-06-02-02-02-03.wav</td>
#     </tr>
#     <tr>
#       <th id="T_03cbc_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_03cbc_row2_col0" class="data row2 col0" >surprise</td>
#       <td id="T_03cbc_row2_col1" class="data row2 col1" >/root/.cache/kagglehub/datasets/dmitrybabko/speech-emotion-recognition-en/versions/1/Ravdess/audio_speech_actors_01-24/Actor_03/03-01-08-02-01-02-03.wav</td>
#     </tr>
#     <tr>
#       <th id="T_03cbc_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_03cbc_row3_col0" class="data row3 col0" >surprise</td>
#       <td id="T_03cbc_row3_col1" class="data row3 col1" >/root/.cache/kagglehub/datasets/dmitrybabko/speech-emotion-recognition-en/versions/1/Ravdess/audio_speech_actors_01-24/Actor_03/03-01-08-02-02-02-03.wav</td>
#     </tr>
#     <tr>
#       <th id="T_03cbc_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_03cbc_row4_col0" class="data row4 col0" >surprise</td>
#       <td id="T_03cbc_row4_col1" class="data row4 col1" >/root/.cache/kagglehub/datasets/dmitrybabko/speech-emotion-recognition-en/versions/1/Ravdess/audio_speech_actors_01-24/Actor_03/03-01-08-01-01-02-03.wav</td>
#     </tr>
#   </tbody>
# </table>

# %%
[Ravdess_df["Emotions"].unique().tolist() for i in Ravdess_df.columns]
# Out:
# [['calm', 'fear', 'surprise', 'disgust', 'angry', 'sad', 'happy', 'neutral'],
#  ['calm', 'fear', 'surprise', 'disgust', 'angry', 'sad', 'happy', 'neutral']]

# %%
sns.set(style="whitegrid", color_codes=True)
plt.figure(figsize=(20,10),dpi=200)
Count_emotion = Ravdess_df['Emotions'].value_counts()[:]
ax = sns.barplot(x= Count_emotion, y= Count_emotion.index, palette="mako")
ax.bar_label(ax.containers[0],fontsize=16)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.ylabel("Name of Emotions", fontdict= font1)
plt.xlabel("Count of Emotions", fontdict= font1)
plt.title("Emotions - Count", fontdict= font1)
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.

# %%
Ex_Savee_dir_list = Savee_dir_list[:15]
Ex_Savee_dir_list
# Out:
# ['JK_f06.wav',
#  'KL_d06.wav',
#  'JE_n06.wav',
#  'JK_f13.wav',
#  'JK_f11.wav',
#  'DC_a13.wav',
#  'KL_su09.wav',
#  'DC_a05.wav',
#  'DC_sa02.wav',
#  'KL_a09.wav',
#  'KL_sa01.wav',
#  'KL_n13.wav',
#  'JK_n26.wav',
#  'KL_sa07.wav',
#  'JE_n10.wav']

# %%
emotions_savee = []
path_savee = []

for it in Savee_dir_list:
    path_savee.append(Savee_path + it)
    part = it.split('_')[1]
    part = part[:-6]
    if part == 'a':
        emotions_savee.append('angry')
    elif part == 'd':
        emotions_savee.append('disgust')
    elif part == 'f':
        emotions_savee.append('fear')
    elif part == 'h':
        emotions_savee.append('happiness')
    elif part == 'n':
        emotions_savee.append('neutral')
    elif part == 'sa':
        emotions_savee.append('sadness')
    elif part == 'su':
        emotions_savee.append('surprise')

    else:
        emotions_savee.append('Unknown')

# dataframe for emotion of files
emotion_savee_df = pd.DataFrame(emotions_savee, columns=['Emotions'])

# dataframe for path of files.
path_savee_df = pd.DataFrame(path_savee, columns=['Path'])
Savee_df = pd.concat([emotion_savee_df, path_savee_df], axis=1)
Savee_df.head().style.set_properties(**{'background-color': '#9490ff',
                           'color': 'black',
                           'border-color': 'black'})
# Out:
# <style type="text/css">
# #T_da678_row0_col0, #T_da678_row0_col1, #T_da678_row1_col0, #T_da678_row1_col1, #T_da678_row2_col0, #T_da678_row2_col1, #T_da678_row3_col0, #T_da678_row3_col1, #T_da678_row4_col0, #T_da678_row4_col1 {
#   background-color: #9490ff;
#   color: black;
#   border-color: black;
# }
# </style>
# <table id="T_da678" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_da678_level0_col0" class="col_heading level0 col0" >Emotions</th>
#       <th id="T_da678_level0_col1" class="col_heading level0 col1" >Path</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_da678_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_da678_row0_col0" class="data row0 col0" >fear</td>
#       <td id="T_da678_row0_col1" class="data row0 col1" >/root/.cache/kagglehub/datasets/dmitrybabko/speech-emotion-recognition-en/versions/1/Savee/JK_f06.wav</td>
#     </tr>
#     <tr>
#       <th id="T_da678_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_da678_row1_col0" class="data row1 col0" >disgust</td>
#       <td id="T_da678_row1_col1" class="data row1 col1" >/root/.cache/kagglehub/datasets/dmitrybabko/speech-emotion-recognition-en/versions/1/Savee/KL_d06.wav</td>
#     </tr>
#     <tr>
#       <th id="T_da678_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_da678_row2_col0" class="data row2 col0" >neutral</td>
#       <td id="T_da678_row2_col1" class="data row2 col1" >/root/.cache/kagglehub/datasets/dmitrybabko/speech-emotion-recognition-en/versions/1/Savee/JE_n06.wav</td>
#     </tr>
#     <tr>
#       <th id="T_da678_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_da678_row3_col0" class="data row3 col0" >fear</td>
#       <td id="T_da678_row3_col1" class="data row3 col1" >/root/.cache/kagglehub/datasets/dmitrybabko/speech-emotion-recognition-en/versions/1/Savee/JK_f13.wav</td>
#     </tr>
#     <tr>
#       <th id="T_da678_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_da678_row4_col0" class="data row4 col0" >fear</td>
#       <td id="T_da678_row4_col1" class="data row4 col1" >/root/.cache/kagglehub/datasets/dmitrybabko/speech-emotion-recognition-en/versions/1/Savee/JK_f11.wav</td>
#     </tr>
#   </tbody>
# </table>

# %%
[Savee_df["Emotions"].unique().tolist() for i in Savee_df.columns]
# Out:
# [['fear', 'disgust', 'neutral', 'angry', 'surprise', 'sadness', 'happiness'],
#  ['fear', 'disgust', 'neutral', 'angry', 'surprise', 'sadness', 'happiness']]

# %%
sns.set(style="whitegrid", color_codes=True)
plt.figure(figsize=(20,10),dpi=200)
Count_emotion = Savee_df['Emotions'].value_counts()[:]
ax = sns.barplot(x= Count_emotion, y= Count_emotion.index, palette="mako")
ax.bar_label(ax.containers[0],fontsize=16)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.ylabel("Name of Emotions", fontdict= font1)
plt.xlabel("Count of Emotions", fontdict= font1)
plt.title("Emotions - Count", fontdict= font1)
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.

# %%
Ex_Tess_dir_list = Tess_dir_list[:15]
Ex_Tess_dir_list
# Out:
# ['OAF_happy',
#  'OAF_Fear',
#  'OAF_neutral',
#  'OAF_Sad',
#  'YAF_pleasant_surprised',
#  'YAF_happy',
#  'OAF_angry',
#  'YAF_angry',
#  'YAF_sad',
#  'YAF_disgust',
#  'YAF_fear',
#  'YAF_neutral',
#  'OAF_Pleasant_surprise',
#  'OAF_disgust']

# %%
emotions_tess = []
path_tess = []

for it in Tess_dir_list:
    directories = os.listdir(Tess_path + '/' + it)
    for file in directories:
        part = file.split('.')[0]
        part = part.split('_')[2]
        if part=='ps':
            emotions_tess.append('surprise')
        else:
            emotions_tess.append(part)
        path_tess.append(Tess_path + it + '/' + file)



# dataframe for emotion of files
emotion_tess_df = pd.DataFrame(emotions_tess, columns=['Emotions'])

# dataframe for path of files.
path_tess_df = pd.DataFrame(path_tess, columns=['Path'])
Tess_df = pd.concat([emotion_tess_df, path_tess_df], axis=1)
Tess_df.head().style.set_properties(**{'background-color': '#9490ff',
                           'color': 'black',
                           'border-color': 'black'})
# Out:
# <style type="text/css">
# #T_d0d36_row0_col0, #T_d0d36_row0_col1, #T_d0d36_row1_col0, #T_d0d36_row1_col1, #T_d0d36_row2_col0, #T_d0d36_row2_col1, #T_d0d36_row3_col0, #T_d0d36_row3_col1, #T_d0d36_row4_col0, #T_d0d36_row4_col1 {
#   background-color: #9490ff;
#   color: black;
#   border-color: black;
# }
# </style>
# <table id="T_d0d36" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d0d36_level0_col0" class="col_heading level0 col0" >Emotions</th>
#       <th id="T_d0d36_level0_col1" class="col_heading level0 col1" >Path</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d0d36_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d0d36_row0_col0" class="data row0 col0" >happy</td>
#       <td id="T_d0d36_row0_col1" class="data row0 col1" >/root/.cache/kagglehub/datasets/dmitrybabko/speech-emotion-recognition-en/versions/1/Tess/OAF_happy/OAF_food_happy.wav</td>
#     </tr>
#     <tr>
#       <th id="T_d0d36_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d0d36_row1_col0" class="data row1 col0" >happy</td>
#       <td id="T_d0d36_row1_col1" class="data row1 col1" >/root/.cache/kagglehub/datasets/dmitrybabko/speech-emotion-recognition-en/versions/1/Tess/OAF_happy/OAF_shack_happy.wav</td>
#     </tr>
#     <tr>
#       <th id="T_d0d36_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d0d36_row2_col0" class="data row2 col0" >happy</td>
#       <td id="T_d0d36_row2_col1" class="data row2 col1" >/root/.cache/kagglehub/datasets/dmitrybabko/speech-emotion-recognition-en/versions/1/Tess/OAF_happy/OAF_chain_happy.wav</td>
#     </tr>
#     <tr>
#       <th id="T_d0d36_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d0d36_row3_col0" class="data row3 col0" >happy</td>
#       <td id="T_d0d36_row3_col1" class="data row3 col1" >/root/.cache/kagglehub/datasets/dmitrybabko/speech-emotion-recognition-en/versions/1/Tess/OAF_happy/OAF_lot_happy.wav</td>
#     </tr>
#     <tr>
#       <th id="T_d0d36_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d0d36_row4_col0" class="data row4 col0" >happy</td>
#       <td id="T_d0d36_row4_col1" class="data row4 col1" >/root/.cache/kagglehub/datasets/dmitrybabko/speech-emotion-recognition-en/versions/1/Tess/OAF_happy/OAF_wife_happy.wav</td>
#     </tr>
#   </tbody>
# </table>

# %%
[Tess_df["Emotions"].unique().tolist() for i in Tess_df.columns]
# Out:
# [['happy', 'fear', 'neutral', 'sad', 'surprise', 'angry', 'disgust'],
#  ['happy', 'fear', 'neutral', 'sad', 'surprise', 'angry', 'disgust']]

# %%
sns.set(style="whitegrid", color_codes=True)
plt.figure(figsize=(20,10),dpi=200)
Count_emotion = Tess_df['Emotions'].value_counts()[:]
ax = sns.barplot(x= Count_emotion, y= Count_emotion.index, palette="mako")
ax.bar_label(ax.containers[0],fontsize=16)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.ylabel("Name of Emotions", fontdict= font1)
plt.xlabel("Count of Emotions", fontdict= font1)
plt.title("Emotions - Count", fontdict= font1)
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.

# %%
Sum_df = pd.concat([Crema_df, Ravdess_df, Savee_df, Tess_df], axis = 0)
Sum_df.to_csv("Sum_df.csv",index=False)
Sum_df.head().style.set_properties(**{'background-color': '#9490ff',
                           'color': 'black',
                           'border-color': 'black'})
# Out:
# <style type="text/css">
# #T_cf06a_row0_col0, #T_cf06a_row0_col1, #T_cf06a_row1_col0, #T_cf06a_row1_col1, #T_cf06a_row2_col0, #T_cf06a_row2_col1, #T_cf06a_row3_col0, #T_cf06a_row3_col1, #T_cf06a_row4_col0, #T_cf06a_row4_col1 {
#   background-color: #9490ff;
#   color: black;
#   border-color: black;
# }
# </style>
# <table id="T_cf06a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cf06a_level0_col0" class="col_heading level0 col0" >Emotions</th>
#       <th id="T_cf06a_level0_col1" class="col_heading level0 col1" >Path</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cf06a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cf06a_row0_col0" class="data row0 col0" >disgust</td>
#       <td id="T_cf06a_row0_col1" class="data row0 col1" >/root/.cache/kagglehub/datasets/dmitrybabko/speech-emotion-recognition-en/versions/1/Crema/1074_IWW_DIS_XX.wav</td>
#     </tr>
#     <tr>
#       <th id="T_cf06a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cf06a_row1_col0" class="data row1 col0" >disgust</td>
#       <td id="T_cf06a_row1_col1" class="data row1 col1" >/root/.cache/kagglehub/datasets/dmitrybabko/speech-emotion-recognition-en/versions/1/Crema/1090_MTI_DIS_XX.wav</td>
#     </tr>
#     <tr>
#       <th id="T_cf06a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cf06a_row2_col0" class="data row2 col0" >happy</td>
#       <td id="T_cf06a_row2_col1" class="data row2 col1" >/root/.cache/kagglehub/datasets/dmitrybabko/speech-emotion-recognition-en/versions/1/Crema/1046_IEO_HAP_LO.wav</td>
#     </tr>
#     <tr>
#       <th id="T_cf06a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cf06a_row3_col0" class="data row3 col0" >fear</td>
#       <td id="T_cf06a_row3_col1" class="data row3 col1" >/root/.cache/kagglehub/datasets/dmitrybabko/speech-emotion-recognition-en/versions/1/Crema/1032_IWW_FEA_XX.wav</td>
#     </tr>
#     <tr>
#       <th id="T_cf06a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_cf06a_row4_col0" class="data row4 col0" >disgust</td>
#       <td id="T_cf06a_row4_col1" class="data row4 col1" >/root/.cache/kagglehub/datasets/dmitrybabko/speech-emotion-recognition-en/versions/1/Crema/1084_IEO_DIS_LO.wav</td>
#     </tr>
#   </tbody>
# </table>

# %%
[Sum_df["Emotions"].unique().tolist() for i in Sum_df.columns]
# Out:
# [['disgust',
#   'happy',
#   'fear',
#   'neutral',
#   'angry',
#   'sad',
#   'calm',
#   'surprise',
#   'sadness',
#   'happiness'],
#  ['disgust',
#   'happy',
#   'fear',
#   'neutral',
#   'angry',
#   'sad',
#   'calm',
#   'surprise',
#   'sadness',
#   'happiness']]

# %%
sns.set(style="whitegrid", color_codes=True)
plt.figure(figsize=(20,10),dpi=200)
Count_emotion = Sum_df['Emotions'].value_counts()[:]
ax = sns.barplot(x= Count_emotion, y= Count_emotion.index, palette="mako")
ax.bar_label(ax.containers[0],fontsize=16)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.ylabel("Name of Emotions", fontdict= font1)
plt.xlabel("Count of Emotions", fontdict= font1)
plt.title("Emotions - Count", fontdict= font1)
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.

# %%
Sum_df_rep = Sum_df
Sum_df_rep['Emotions'].replace('happiness', 'happy', inplace=True)
Sum_df_rep['Emotions'].replace('sadness', 'sad', inplace=True)
Sum_df_rep['Emotions'].replace('calm', 'neutral', inplace=True)

# %%
[Sum_df_rep["Emotions"].unique().tolist() for i in Sum_df_rep.columns]
# Out:
# [['disgust', 'happy', 'fear', 'neutral', 'angry', 'sad', 'surprise'],
#  ['disgust', 'happy', 'fear', 'neutral', 'angry', 'sad', 'surprise']]

# %%
sns.set(style="whitegrid", color_codes=True)
plt.figure(figsize=(20,10),dpi=200)
Count_emotion = Sum_df_rep['Emotions'].value_counts()[:]
ax = sns.barplot(x= Count_emotion, y= Count_emotion.index, palette="mako")
ax.bar_label(ax.containers[0],fontsize=16)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.ylabel("Name of Emotions", fontdict= font1)
plt.xlabel("Count of Emotions", fontdict= font1)
plt.title("Emotions - Count", fontdict= font1)
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.

# %%
print(Sum_df)
# Out:
#      Emotions                                               Path
# 0     disgust  /root/.cache/kagglehub/datasets/dmitrybabko/sp...
# 1     disgust  /root/.cache/kagglehub/datasets/dmitrybabko/sp...
# 2       happy  /root/.cache/kagglehub/datasets/dmitrybabko/sp...
# 3        fear  /root/.cache/kagglehub/datasets/dmitrybabko/sp...
# 4     disgust  /root/.cache/kagglehub/datasets/dmitrybabko/sp...
# ...       ...                                                ...
# 2795  disgust  /root/.cache/kagglehub/datasets/dmitrybabko/sp...
# 2796  disgust  /root/.cache/kagglehub/datasets/dmitrybabko/sp...
# 2797  disgust  /root/.cache/kagglehub/datasets/dmitrybabko/sp...
# 2798  disgust  /root/.cache/kagglehub/datasets/dmitrybabko/sp...
# 2799  disgust  /root/.cache/kagglehub/datasets/dmitrybabko/sp...
#
# [12162 rows x 2 columns]

# %%
# label_map = {label: idx for idx, label in enumerate(Sum_df['Emotions'].unique())}
# inverse_label_map = {idx: label for label, idx in label_map.items()}
# Sum_df['Emotions'] = Sum_df['Emotions'].map(label_map)
# Sum_df.head(2)

# %%
def waveplot(data, sr, emotion):
    plt.figure(figsize=(10,4))
    plt.title(emotion, size=20)
    librosa.display.waveshow(data, sr=sr)
    plt.show()

def spectogram(data, sr, emotion):
    x = librosa.stft(data)
    xdb = librosa.amplitude_to_db(abs(x))
    plt.figure(figsize=(11,4))
    plt.title(emotion, size=20)
    librosa.display.specshow(xdb, sr=sr, x_axis='time', y_axis='hz')
    plt.colorbar()

# %%
filtered_rows = Sum_df[Sum_df['Emotions'].str.strip().str.lower() == 'angry']
print(filtered_rows)
# Out:
#      Emotions                                               Path
# 6       angry  /root/.cache/kagglehub/datasets/dmitrybabko/sp...
# 13      angry  /root/.cache/kagglehub/datasets/dmitrybabko/sp...
# 18      angry  /root/.cache/kagglehub/datasets/dmitrybabko/sp...
# 21      angry  /root/.cache/kagglehub/datasets/dmitrybabko/sp...
# 22      angry  /root/.cache/kagglehub/datasets/dmitrybabko/sp...
# ...       ...                                                ...
# 1595    angry  /root/.cache/kagglehub/datasets/dmitrybabko/sp...
# 1596    angry  /root/.cache/kagglehub/datasets/dmitrybabko/sp...
# 1597    angry  /root/.cache/kagglehub/datasets/dmitrybabko/sp...
# 1598    angry  /root/.cache/kagglehub/datasets/dmitrybabko/sp...
# 1599    angry  /root/.cache/kagglehub/datasets/dmitrybabko/sp...
#
# [1923 rows x 2 columns]

# %%
emotion = 'fear'
path = np.array(Sum_df['Path'][Sum_df['Emotions']== emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'angry'
path = np.array(Sum_df['Path'][Sum_df['Emotions']==emotion])[1]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'disgust'
path = np.array(Sum_df['Path'][Sum_df['Emotions']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'neutral'
path = np.array(Sum_df['Path'][Sum_df['Emotions']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'sad'
path = np.array(Sum_df['Path'][Sum_df['Emotions']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'surprise'
path = np.array(Sum_df['Path'][Sum_df['Emotions']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'happy'
path = np.array(Sum_df['Path'][Sum_df['Emotions']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# convert labels to integers
label_map = {label: idx for idx, label in enumerate(Sum_df['Emotions'].unique())}
inverse_label_map = {idx: label for label, idx in label_map.items()}
Sum_df['Emotions'] = Sum_df['Emotions'].map(label_map)
Sum_df.head(2)
# Out:
#    Emotions                                               Path
# 0         0  /root/.cache/kagglehub/datasets/dmitrybabko/sp...
# 1         0  /root/.cache/kagglehub/datasets/dmitrybabko/sp...

# %%
import random
import numpy as np
import librosa
import torch
from torchaudio.transforms import TimeMasking, FrequencyMasking


def augment_audio(audio, sampling_rate):
    """
    Apply data augmentation to audio, including noise induction, pitch shifting, and SpecAugment.
    """
    # Apply noise
    if random.random() < 0.5:  # 50% chance
        noise = np.random.normal(0, 0.005, audio.shape)
        audio = audio + noise
        audio = np.clip(audio, -1.0, 1.0)

    # Apply pitch shifting
    if random.random() < 0.5:  # 50% chance
        pitch_factor = random.randint(-2, 2)  # Shift pitch by -2 to 2 semitones
        audio = librosa.effects.pitch_shift(audio, sr=sampling_rate, n_steps=pitch_factor)

    # Apply SpecAugment
    if random.random() < 0.5:  # 50% chance
        mel_spectrogram = librosa.feature.melspectrogram(y=audio, sr=sampling_rate)
        log_mel_spectrogram = librosa.power_to_db(mel_spectrogram, ref=np.max)

        # Convert to torch tensor for SpecAugment
        spec = torch.tensor(log_mel_spectrogram, dtype=torch.float32)
        time_mask = TimeMasking(time_mask_param=30)
        freq_mask = FrequencyMasking(freq_mask_param=15)

        # Apply masks
        spec = time_mask(spec)
        spec = freq_mask(spec)

        # Convert back to numpy array
        audio = librosa.feature.inverse.mel_to_audio(spec.numpy(), sr=sampling_rate)

    return audio

# %%
class SpeechEmotionDataset(Dataset):
    def __init__(self, Sum_df, processor, max_length=32000):
        self.Sum_df = Sum_df
        self.processor = processor
        self.max_length = max_length

    def __len__(self):
        return len(self.Sum_df)

    def __getitem__(self, idx):
        audio_path = self.Sum_df.iloc[idx]['Path']
        label = self.Sum_df.iloc[idx]['Emotions']

        # Load the audio file
        speech, sr = librosa.load(audio_path, sr=16000)

        # Apply augmentations
        speech = augment_audio(speech, sr)

        # Pad or truncate the speech to the required length
        if len(speech) > self.max_length:
            speech = speech[:self.max_length]
        else:
            speech = np.pad(speech, (0, self.max_length - len(speech)), 'constant')

        # Preprocess the audio file
        inputs = self.processor(
            speech,
            sampling_rate=sr,
            return_tensors='pt',
            padding=True,
            truncation=True,
            max_length=self.max_length
        )

        input_values = inputs.input_values.squeeze()
        return {'input_values': input_values, 'labels': torch.tensor(label, dtype=torch.long)}

# %%
# split the data for train and test
from sklearn.model_selection import train_test_split
train_df, test_df = train_test_split(Sum_df, test_size=0.2, random_state=42)

# %%
# initialize the processor and model
processor = Wav2Vec2Processor.from_pretrained('facebook/wav2vec2-base')
model = Wav2Vec2ForSequenceClassification.from_pretrained('facebook/wav2vec2-base', num_labels=7)
# Out:
# preprocessor_config.json:   0%|          | 0.00/159 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/163 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.84k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/291 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/85.0 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/380M [00:00<?, ?B/s]
# Some weights of Wav2Vec2ForSequenceClassification were not initialized from the model checkpoint at facebook/wav2vec2-base and are newly initialized: ['classifier.bias', 'classifier.weight', 'projector.bias', 'projector.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# load the dataset
train_dataset = SpeechEmotionDataset(train_df, processor)
test_dataset = SpeechEmotionDataset(test_df, processor)

# %%
train_dataset[0]['input_values'].size()
# Out:
# torch.Size([32000])

# %%
training_args = TrainingArguments(
    output_dir='./results',
    evaluation_strategy='steps',
    save_strategy='steps',
    eval_steps=250,
    save_steps=250,
    save_total_limit=2,
    learning_rate=1e-5,
    lr_scheduler_type='linear',
    warmup_steps=500,
    per_device_train_batch_size=8,
    gradient_accumulation_steps=2,
    per_device_eval_batch_size=8,
    num_train_epochs=10,
    weight_decay=0.1,
    load_best_model_at_end=True,
    metric_for_best_model='f1',
    greater_is_better=True,
    fp16=True,
    logging_dir='./logs',
    logging_steps=100,
    report_to=["tensorboard"]
)

# %%
# create functions for computing metrics
from sklearn.metrics import accuracy_score, precision_recall_fscore_support

def compute_metrics(pred):
    labels = pred.label_ids # original labels
    preds = np.argmax(pred.predictions, axis=1) # model predicted labels
    accuracy = accuracy_score(labels, preds)
    precision, recall, f1, _ = precision_recall_fscore_support(labels, preds, average='weighted')
    return {
        "accuracy": accuracy,
        "precision": precision,
        "recall": recall,
        "f1": f1
    }

# %%
# initialize the trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=test_dataset,
    compute_metrics=compute_metrics
)
trainer.train()
# Out:
#     <div>
#
#       <progress value='6080' max='6080' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [6080/6080 18:05:11, Epoch 9/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>250</td>
#       <td>1.924500</td>
#       <td>1.909036</td>
#       <td>0.198109</td>
#       <td>0.195296</td>
#       <td>0.198109</td>
#       <td>0.179369</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>1.880600</td>
#       <td>1.864053</td>
#       <td>0.228935</td>
#       <td>0.239023</td>
#       <td>0.228935</td>
#       <td>0.179589</td>
#     </tr>
#     <tr>
#       <td>750</td>
#       <td>1.835700</td>
#       <td>1.823254</td>
#       <td>0.241677</td>
#       <td>0.236885</td>
#       <td>0.241677</td>
#       <td>0.216723</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>1.774500</td>
#       <td>1.773154</td>
#       <td>0.271270</td>
#       <td>0.298410</td>
#       <td>0.271270</td>
#       <td>0.273583</td>
#     </tr>
#     <tr>
#       <td>1250</td>
#       <td>1.751800</td>
#       <td>1.749725</td>
#       <td>0.274147</td>
#       <td>0.297513</td>
#       <td>0.274147</td>
#       <td>0.252948</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>1.700900</td>
#       <td>1.671925</td>
#       <td>0.332100</td>
#       <td>0.384892</td>
#       <td>0.332100</td>
#       <td>0.317714</td>
#     </tr>
#     <tr>
#       <td>1750</td>
#       <td>1.649800</td>
#       <td>1.615894</td>
#       <td>0.364570</td>
#       <td>0.406398</td>
#       <td>0.364570</td>
#       <td>0.355356</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>1.597000</td>
#       <td>1.568866</td>
#       <td>0.406494</td>
#       <td>0.451069</td>
#       <td>0.406494</td>
#       <td>0.391511</td>
#     </tr>
#     <tr>
#       <td>2250</td>
#       <td>1.560700</td>
#       <td>1.532377</td>
#       <td>0.404028</td>
#       <td>0.437387</td>
#       <td>0.404028</td>
#       <td>0.391896</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>1.526800</td>
#       <td>1.483349</td>
#       <td>0.428689</td>
#       <td>0.476046</td>
#       <td>0.428689</td>
#       <td>0.433934</td>
#     </tr>
#     <tr>
#       <td>2750</td>
#       <td>1.469600</td>
#       <td>1.498056</td>
#       <td>0.425401</td>
#       <td>0.493915</td>
#       <td>0.425401</td>
#       <td>0.413679</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>1.455000</td>
#       <td>1.469382</td>
#       <td>0.433210</td>
#       <td>0.487586</td>
#       <td>0.433210</td>
#       <td>0.424201</td>
#     </tr>
#     <tr>
#       <td>3250</td>
#       <td>1.447300</td>
#       <td>1.450525</td>
#       <td>0.425401</td>
#       <td>0.468842</td>
#       <td>0.425401</td>
#       <td>0.412817</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>1.413400</td>
#       <td>1.420686</td>
#       <td>0.440608</td>
#       <td>0.543058</td>
#       <td>0.440608</td>
#       <td>0.451363</td>
#     </tr>
#     <tr>
#       <td>3750</td>
#       <td>1.396300</td>
#       <td>1.424225</td>
#       <td>0.442663</td>
#       <td>0.459325</td>
#       <td>0.442663</td>
#       <td>0.444048</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>1.390900</td>
#       <td>1.372332</td>
#       <td>0.463214</td>
#       <td>0.504196</td>
#       <td>0.463214</td>
#       <td>0.470653</td>
#     </tr>
#     <tr>
#       <td>4250</td>
#       <td>1.353900</td>
#       <td>1.380997</td>
#       <td>0.451295</td>
#       <td>0.479712</td>
#       <td>0.451295</td>
#       <td>0.453077</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>1.356100</td>
#       <td>1.385209</td>
#       <td>0.459515</td>
#       <td>0.497737</td>
#       <td>0.459515</td>
#       <td>0.460853</td>
#     </tr>
#     <tr>
#       <td>4750</td>
#       <td>1.373000</td>
#       <td>1.390571</td>
#       <td>0.450473</td>
#       <td>0.501892</td>
#       <td>0.450473</td>
#       <td>0.453958</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>1.381200</td>
#       <td>1.363566</td>
#       <td>0.473079</td>
#       <td>0.497470</td>
#       <td>0.473079</td>
#       <td>0.471526</td>
#     </tr>
#     <tr>
#       <td>5250</td>
#       <td>1.320800</td>
#       <td>1.382471</td>
#       <td>0.453761</td>
#       <td>0.515326</td>
#       <td>0.453761</td>
#       <td>0.457408</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>1.302500</td>
#       <td>1.369593</td>
#       <td>0.464858</td>
#       <td>0.496300</td>
#       <td>0.464858</td>
#       <td>0.468341</td>
#     </tr>
#     <tr>
#       <td>5750</td>
#       <td>1.310900</td>
#       <td>1.357286</td>
#       <td>0.468146</td>
#       <td>0.513478</td>
#       <td>0.468146</td>
#       <td>0.474614</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>1.326400</td>
#       <td>1.349069</td>
#       <td>0.468557</td>
#       <td>0.511715</td>
#       <td>0.468557</td>
#       <td>0.474124</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=6080, training_loss=1.520615664281343, metrics={'train_runtime': 65124.7281, 'train_samples_per_second': 1.494, 'train_steps_per_second': 0.093, 'total_flos': 1.765218844104e+18, 'train_loss': 1.520615664281343, 'epoch': 9.99178307313065})

# %%
results = trainer.evaluate()
print(results)
# Out:
#     <div>
#
#       <progress value='305' max='305' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [305/305 16:57]
#     </div>
# {'eval_loss': 1.356513500213623, 'eval_accuracy': 0.4562268803945746, 'eval_precision': 0.5011706868602454, 'eval_recall': 0.4562268803945746, 'eval_f1': 0.46425853260991545, 'eval_runtime': 1024.4491, 'eval_samples_per_second': 2.375, 'eval_steps_per_second': 0.298, 'epoch': 9.99178307313065}

# %%
import random
idx = random.randrange(0, len(test_dataset))
print("Original Label:", inverse_label_map[int(test_dataset[idx]['labels'])])
input_values = test_dataset[idx]['input_values'].unsqueeze(0).to('cuda')

with torch.no_grad():
    outputs = model(input_values)
logits = outputs.logits

predicted_class = logits.argmax(dim=-1).item()
print('Predicted Label:', inverse_label_map[predicted_class])
# Out:
# Original Label: disgust
# Predicted Label: disgust

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
from transformers import Wav2Vec2Processor, Wav2Vec2ForSequenceClassification

model_save_path = "/content/saved_model4"
model.wav2vec2.save_pretrained(model_save_path)
processor.save_pretrained(model_save_path)
# Out:
# []

# %%
from huggingface_hub import HfApi, upload_folder

# Define the name for your Hugging Face model repository
model_repo_name = "sagir567/wav2vec2transformerEMR4"  # Replace this with your preferred repository name

# Create a new repository (if it doesn't already exist)
HfApi().create_repo(repo_id=model_repo_name, exist_ok=True)

# Upload the model directory to Hugging Face
upload_folder(
    folder_path="/content/saved_model4",  # Path to the saved model directory
    repo_id=model_repo_name,
    commit_message="Initial model upload for speech emotion recognition"
)
# Out:
# model.safetensors:   0%|          | 0.00/378M [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/sagir567/wav2vec2transformerEMR4/commit/27a05e953f33308a91d1c9eb7fcb6b767a8bd9f3', commit_message='Initial model upload for speech emotion recognition', commit_description='', oid='27a05e953f33308a91d1c9eb7fcb6b767a8bd9f3', pr_url=None, repo_url=RepoUrl('https://huggingface.co/sagir567/wav2vec2transformerEMR4', endpoint='https://huggingface.co', repo_type='model', repo_id='sagir567/wav2vec2transformerEMR4'), pr_revision=None, pr_num=None)

# %%
trainer.args.output_dir = 'sagir567/wav2vec2transformerEMR4'
trainer.push_to_hub()
# Out:
# Upload 2 LFS files:   0%|          | 0/2 [00:00<?, ?it/s]
# model.safetensors:   0%|          | 0.00/378M [00:00<?, ?B/s]
# training_args.bin:   0%|          | 0.00/5.24k [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/sagir567/wav2vec2transformerEMR4/commit/66d8adf4ce5764ef18d1b3f18f17c977c7a38889', commit_message='End of training', commit_description='', oid='66d8adf4ce5764ef18d1b3f18f17c977c7a38889', pr_url=None, repo_url=RepoUrl('https://huggingface.co/sagir567/wav2vec2transformerEMR4', endpoint='https://huggingface.co', repo_type='model', repo_id='sagir567/wav2vec2transformerEMR4'), pr_revision=None, pr_num=None)
